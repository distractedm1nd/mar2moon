# %% [markdown]
# # Approach 1: Yahoo Finance

# %%
#pip install yfinance

# %%
import yfinance as yf
from datetime import date

# %%
# see: https://github.com/ranaroussi/yfinance

btc = yf.Ticker("BTC-USD")

# get stock info
btc.info

# get historical market data
btc = btc.history(period="ytd")
btc.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# 2021-01-05  31977.041016  34437.589844  30221.187500  33992.429688
#
#                  Volume  Dividends  Stock Splits
# Date
# 2021-01-01  40730301359          0             0
# 2021-01-02  67865420765          0             0
# 2021-01-03  78665235202          0             0
# 2021-01-04  81163475344          0             0
# 2021-01-05  67547324782          0             0

# %%
#data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")
all_coins_daily_ytd = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "BTC-USD ETH-USD DOGE-USD",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )

#print(all_coins_daily_ytd)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
all_coins_daily_ytd.head()
# Out:
#                 ETH-USD                                                     \
#                    Open         High         Low        Close       Volume
# Date
# 2021-01-01   737.708374   749.201843  719.792236   730.367554  13652004358
# 2021-01-02   730.402649   786.798462  718.109497   774.534973  19740771179
# 2021-01-03   774.511841  1006.565002  771.561646   975.507690  45200463368
# 2021-01-04   977.058838  1153.189209  912.305359  1040.233032  56945985763
# 2021-01-05  1041.498779  1129.371460  986.811279  1100.006104  41535932781
#
#                  BTC-USD                                            \
#                     Open          High           Low         Close
# Date
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# ...

# %%
# BTC-DOGE-ETH - Daily - Year-to-Date
today = date.today().strftime('%Y-%m-%d')
coin_prices_path = '../coin-prices/'
all_coins_daily_ytd_file_name = 'all_coins_daily_ytd_' + today + '.csv'
#print(all_coins_daily_ytd_file_name)
full_path_name = coin_prices_path + all_coins_daily_ytd_file_name
#print(full_path_name)
all_coins_daily_ytd.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)

# %%
# BTC-DOGE-ETH - Daily - 2-Year-Period
all_coins_daily_2y = yf.download(
        tickers = "BTC-USD ETH-USD DOGE-USD",
        period = "2y",
        interval = "1d",
        group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
coin_prices_path = '../coin-prices/'
all_coins_daily_2y_file_name = 'all_coins_daily_2y_' + today + '.csv'
#print(all_coins_daily_2y_file_name)
full_path_name = coin_prices_path + all_coins_daily_2y_file_name
#print(full_path_name)
all_coins_daily_2y.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# BTC-DOGE-ETH - Weekly - 2-Year-Period
all_coins_weekly_2y = yf.download(
        tickers = "BTC-USD ETH-USD DOGE-USD",
        period = "2y",
        interval = "1wk",
        group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
coin_prices_path = '../coin-prices/'
all_coins_weekly_2y_file_name = 'all_coins_weekly_2y_' + today + '.csv'
#print(all_coins_weekly_2y_file_name)
full_path_name = coin_prices_path + all_coins_weekly_2y_file_name
#print(full_path_name)
all_coins_weekly_2y.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# BTC - Daily - 2-Year-Period
btc_daily_2y = yf.download(
        tickers = "BTC-USD",
        period = "2y",
        interval = "1d",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
btc_path = '../coin-prices/btc/'
btc_daily_2y_file_name = 'btc_daily_2y_' + today + '.csv'
#print(btc_ytd_file_name)
full_path_name = btc_path + btc_daily_2y_file_name
#print(path_or_buf)
btc_daily_2y.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# BTC - Daily - YTD
btc_daily_ytd = yf.download(
        tickers = "BTC-USD",
        period = "ytd",
        interval = "1d",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
btc_path = '../coin-prices/btc/'
btc_daily_ytd_file_name = 'btc_daily_ytd_' + today + '.csv'
#print(btc_ytd_file_name)
full_path_name = btc_path + btc_daily_ytd_file_name
#print(full_path_name)
btc_daily_ytd.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# BTC - Weekly - 2-Year-Period
btc_weekly_2y = yf.download(
        tickers = "BTC-USD",
        period = "2y",
        interval = "1wk",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
btc_path = '../coin-prices/btc/'
btc_weekly_2y_file_name = 'btc_weekly_2y_' + today + '.csv'
#print(btc_weekly_2y_file_name)
full_path_name = btc_path + btc_weekly_2y_file_name
#print(full_path_name)
btc_weekly_2y.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# BTC - Weekly - YTD
btc_weekly_ytd = yf.download(
        tickers = "BTC-USD",
        period = "ytd",
        interval = "1wk",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
btc_path = '../coin-prices/btc/'
btc_weekly_ytd_file_name = 'btc_weekly_ytd_' + today + '.csv'
#print(btc_ytd_file_name)
full_path_name = btc_path + btc_weekly_ytd_file_name
#print(full_path_name)
btc_weekly_ytd.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# DOGE - Daily - 2-Year-Period
doge_daily_2y = yf.download(
        tickers = "DOGE-USD",
        period = "2y",
        interval = "1d",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
doge_path = '../coin-prices/doge/'
doge_daily_2y_file_name = 'doge_daily_2y_' + today + '.csv'
#print(doge_daily_2y_file_name)
full_path_name = doge_path + doge_daily_2y_file_name
#print(full_path_name)
doge_daily_2y.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# DOGE - Daily - YTD
doge_daily_ytd = yf.download(
        tickers = "DOGE-USD",
        period = "ytd",
        interval = "1d",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
doge_path = '../coin-prices/doge/'
doge_daily_ytd_file_name = 'doge_daily_ytd_' + today + '.csv'
#print(doge_ytd_file_name)
full_path_name = doge_path + doge_daily_ytd_file_name
#print(full_path_name)
doge_daily_ytd.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# DOGE - Weekly - 2-Year-Period
doge_weekly_2y = yf.download(
        tickers = "DOGE-USD",
        period = "2y",
        interval = "1wk",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
doge_path = '../coin-prices/doge/'
doge_weekly_2y_file_name = 'doge_weekly_2y_' + today + '.csv'
#print(doge_weekly_2y_file_name)
full_path_name = doge_path + doge_weekly_2y_file_name
#print(path_or_buf)
doge_weekly_2y.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# DOGE - Weekly - YTD
doge_weekly_ytd = yf.download(
        tickers = "DOGE-USD",
        period = "ytd",
        interval = "1wk",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
doge_path = '../coin-prices/doge/'
doge_weekly_ytd_file_name = 'doge_weekly_ytd_' + today + '.csv'
#print(doge_ytd_file_name)
full_path_name = doge_path + doge_weekly_ytd_file_name
#print(full_path_name)
doge_weekly_ytd.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# ETH - Daily - 2-Year-Period
eth_daily_2y = yf.download(
        tickers = "ETH-USD",
        period = "ytd",
        interval = "1d",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
eth_path = '../coin-prices/eth/'
eth_daily_2y_file_name = 'eth_daily_2y_' + today + '.csv'
#print(eth_daily_2y_file_name)
full_path_name = eth_path + eth_daily_2y_file_name
#print(full_path_name)
eth_daily_2y.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# ETH - Daily - YTD
eth_daily_ytd = yf.download(
        tickers = "ETH-USD",
        period = "ytd",
        interval = "1d",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
eth_path = '../coin-prices/eth/'
eth_daily_ytd_file_name = 'eth_daily_ytd_' + today + '.csv'
#print(doge_ytd_file_name)
full_path_name = eth_path + eth_daily_ytd_file_name
#print(full_path_name)
eth_daily_ytd.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# ETH - Weekly - 2-Year-Period
eth_weekly_2y = yf.download(
        tickers = "ETH-USD",
        period = "2y",
        interval = "1wk",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
eth_path = '../coin-prices/eth/'
eth_weekly_2y_file_name = 'eth_weekly_2y_' + today + '.csv'
#print(eth_weekly_2y_file_name)
full_path_name = eth_path + eth_weekly_2y_file_name
#print(full_path_name)
eth_weekly_2y.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# ETH - Weekly - YTD
eth_weekly_ytd = yf.download(
        tickers = "ETH-USD",
        period = "ytd",
        interval = "1wk",
        #group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
today = date.today().strftime('%Y-%m-%d')
eth_path = '../coin-prices/eth/'
eth_weekly_ytd_file_name = 'eth_weekly_ytd_' + today + '.csv'
#print(doge_ytd_file_name)
full_path_name = eth_path + eth_weekly_ytd_file_name
#print(full_path_name)
eth_weekly_ytd.to_csv(path_or_buf = full_path_name, encoding = 'utf-8', sep = ',', header = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Approach 2: CoinMarketCap API

# %% [markdown]
# Pure Python connecting to RESTful CoinMarketCap API

# %%
# Official CoinMarketCap API Documentation
# CoinMarketCap: https://coinmarketcap.com/
# CoinMarketCap API Documentation: https://coinmarketcap.com/api/documentation/v1/#section/Quick-Start-Guide
# CoinMarketCap Dev Account: https://pro.coinmarketcap.com/account
# Account Hodler: https://yadim.dismail.de/?ereacud79****

# This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pprint as pp

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  # keep API key secure
  'X-CMC_PRO_API_KEY': 'c9f7557e-eda3-45cf-8094-f4b4466fd2b7',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
  pp.pprint(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %% [markdown]
# Using a python-native wrapper around the CoinMarketCap API

# %%
pip install python-coinmarketcap

# %%
# CMC Map of Coin Names to IDs / symbols / slugs)
# Returns a mapping of all cryptocurrencies to unique CoinMarketCap ids
# CoinMarketCap ID map	
# see: https://coinmarketcap.com/api/documentation/v1/#operation/getV1CryptocurrencyMap

coin_map = cmc.cryptocurrency_map()

# %%
#pp.pprint(coin_map)

import pandas as pd
coin_map_df = pd.DataFrame(coin_map.data, columns =['name', 'symbol', 'slug', 'id'])
coin_map_df.set_index('id', inplace=True)
#print(coin_map_df)
#coin_map_df.head(10)
coins_of_interest = ("BTC", "ETH", "DOGE", "ADA")
coin_map_df.loc[coin_map_df['symbol'].isin(coins_of_interest)]
# Out:
#           name symbol      slug
# id
# 1      Bitcoin    BTC   bitcoin
# 74    Dogecoin   DOGE  dogecoin
# 1027  Ethereum    ETH  ethereum
# 2010   Cardano    ADA   cardano

# %%
from coinmarketcapapi import CoinMarketCapAPI, CoinMarketCapAPIError

# keep API key secure
cmc = CoinMarketCapAPI('c9f7557e-eda3-45cf-8094-f4b4466fd2b7', debug = True)

# %%
# let's try it out with Bitcoin (symbol = 'BTC or slug = 'bitcoin' or id = "1") first
# Returns all static metadata available for one or more cryptocurrencies. This information includes details like logo, description, official website URL, social links, and links to a cryptocurrency's technical documentation. 
# Metadata of 'BTC'
# see: https://coinmarketcap.com/api/documentation/v1/#:~:text=Price%20performance%20Stats-,Metadata,-Returns%20all%20static

btc_info = cmc.cryptocurrency_info(symbol='BTC')
#print(repr(btc_info.data))
pp.pprint(btc_info.data)
# Out:
# 2021-06-21 19:45:17,396 root         DEBUG    GET PRO 'v1/cryptocurrency/info'
# PARAMETERS: {'symbol': 'BTC'}
# ...

# %%
# Returns the latest market quote for 1 or more cryptocurrencies. Use the "convert" option to return market values in multiple fiat and cryptocurrency conversions in the same call.
# historical not supported with free API plan
# see: https://coinmarketcap.com/api/documentation/v1/#operation/getV1CryptocurrencyQuotesLatest

btc_quote_latest = cmc.cryptocurrency_quotes_latest(symbol='BTC', convert='USD')
pp.pprint(btc_quote_latest.data)
# Out:
# 2021-06-21 19:45:20,909 root         DEBUG    GET PRO 'v1/cryptocurrency/quotes/latest'
# PARAMETERS: {'symbol': 'BTC', 'convert': 'USD'}
# ...

# %%
# Returns a paginated list of all active cryptocurrencies with latest market data. 
# historical not supported with free API plan
# see: https://coinmarketcap.com/api/documentation/v1/#operation/getV1CryptocurrencyListingsLatest

btc_listings_latest = cmc.cryptocurrency_listings_latest()
pp.pprint(btc_listings_latest.data)
# Out:
# 2021-06-21 19:42:57,035 root         DEBUG    GET PRO 'v1/cryptocurrency/listings/latest'
# PARAMETERS: {}
# ...

# %%
# API endpoints for global aggregate market data. This category currently includes 2 endpoints:
# historical not supported with free API plan
# see: https://coinmarketcap.com/api/documentation/v1/#tag/global-metrics

global_quotes_latest = cmc.globalmetrics_quotes_latest()
pp.pprint(global_quotes_latest.data)
# Out:
# 2021-06-21 19:53:54,040 root         DEBUG    GET PRO 'v1/global-metrics/quotes/latest'
# PARAMETERS: {}
# ...
