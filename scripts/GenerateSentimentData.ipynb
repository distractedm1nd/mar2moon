# %%
import numpy as np
import pandas as pd
import re
from os import listdir

import SubtitleProcessing

# %%
def prepare_data_for_manual_labelling(subtitle_files, podcast_names, output_file_name, chunk_size, min_chunk_size = 10, filter_labels=None, filter_labels_proportions=None, guess_coin=True):
    """Prepares a csv file for manual sentiment labelling.
    
    Parameters
    ----------
    subtitle_files : list
        Paths to all subtitle files to be used.
    podcast_names : list
        Names of the used podcasts. Ordering must match the subtitle_files list.
    output_file_name : str
        Name of the generated output file.
    chunk_size : int
        Word count of the chunks.
    min_chunk_size : int
        Chunks with less words will be discarded.
    filter_labels : list
        Keep text chunks auto labelled with these labels.
    filter_labels_proportions : list
        Determines how the resulting data will be proportioned based on the auto labels. If there is too much data for specific labels this data will be discarded.
    guess_coin : bool
        Already sets the 'Coin' field based on the Auto_Label
    """
    
    df = pd.DataFrame(columns=["Podcast_Title", "Start_Time", "End_Time", "Auto_Label", "Text", "Coin", "Sentiment"])
    
    for i in range(0,len(subtitle_files)):
        # Get text chunks and their corresponding start and end times
        text_chunks, chunk_start_times, chunk_end_times = SubtitleProcessing.generate_text_chunks(subtitle_files[i], chunk_size, min_chunk_size)
        
        if text_chunks is None:
            continue
        
        # Fill the date in the dataframe
        df_new = pd.DataFrame(columns=df.columns)
        
        text_chunks = [" ".join(chunk) for chunk in text_chunks]
        df_new["Text"] = text_chunks
        
        df_new["Start_Time"] = chunk_start_times
        df_new["End_Time"] = chunk_end_times
        
        df_new["Podcast_Title"] = podcast_names[i]
        
        df_new["Auto_Label"] = [SubtitleProcessing.auto_label_text_chunk_default_labels(t) for t in text_chunks]
        
        df = df.append(df_new, ignore_index=True)

    # Filter and proportion data
    if filter_labels is not None and filter_labels_proportions is not None:
        df = filter_and_balance_by_auto_labels(df, filter_labels, filter_labels_proportions)
    
    if guess_coin:
        df["Coin"][df["Auto_Label"].isin(["BTC","ETH","DOGE"])] = df["Auto_Label"]

    df.to_csv(output_file_name, index=False)


def filter_by_auto_labels(df, filter_labels):
    """Only keeps rows where Auto_Label is in filter_labels
    
    """
    
    return df[df["Auto_Label"].isin(filter_labels)]


def filter_and_balance_by_auto_labels(df, filter_labels, filter_labels_proportions):
    """Prepares a csv file for manual sentiment labelling.
    
    Parameters
    ----------
    df : DataFrame
        Data.
    filter_labels : list
        Keep rows auto labelled with these labels.
    filter_labels_proportions : list
        Determines how the resulting data will be proportioned based on the auto labels. If there is too much data for specific labels this data will be discarded.
    """
    
    if len(df) == 0:
        return df
    
    df = filter_by_auto_labels(df, filter_labels)
    
    total_rows = len(df)
    label_least_data = filter_labels[0]  # The label with the least amount of data relative to the target proportion
    label_least_data_current_percentage = 0
    label_least_data_percentage_to_target = 100
    
    # Find the label with the least amount of data relative to its target proportion of data
    for i in range(0,len(filter_labels)):
        count = sum(df["Auto_Label"] == filter_labels[i])
        current_label_percentage = count / total_rows
        current_label_percentage_to_target = current_label_percentage / filter_labels_proportions[i]
        
        if current_label_percentage_to_target < label_least_data_percentage_to_target:
            label_least_data = i
            label_least_data_current_percentage = current_label_percentage
            label_least_data_percentage_to_target = current_label_percentage_to_target
    
    # Discard data of over represented labels
    new_total_rows = sum(df["Auto_Label"] == filter_labels[label_least_data]) / filter_labels_proportions[label_least_data]
    for i in range(0,len(filter_labels)):
        target_row_count = new_total_rows * filter_labels_proportions[i]  # Targeted row count of the current label
        current_row_count = sum(df["Auto_Label"] == filter_labels[i])
        drop_rows = df[df["Auto_Label"] == filter_labels[i]].sample(n=(current_row_count-int(target_row_count)))  # Pick random rows to drop

        df = df.drop(drop_rows.index)
        df.reset_index(drop=True, inplace=True)
    
    return df

# %%
# Generate Test Sentiment Labelling Data

folder_path = "C:/Users/Tristan/nlp_project/podcast_data/labelling/"
podcast_names = ["altcoin_daily_2021-06-01",
                "altcoin_daily_2021-06-03",
                "altcoin_daily_2021-06-04",
                "altcoin_daily_2021-06-05",
                "altcoin_daily_2021-06-06",
                "altcoin_daily_2021-06-07",
                "altcoin_daily_2021-06-08",
                "altcoin_daily_2021-06-09",
                "altcoin_daily_2021-06-10",
                "altcoin_daily_2021-06-11"]
input_files = list()
for name in podcast_names:
    input_files.append(folder_path + name + ".vtt")

prepare_data_for_manual_labelling(input_files,
                                  podcast_names,
                                  "sentiment_labels_altcoin_daily_210601_to_210611.csv",
                                  30,
                                  filter_labels=["BTC","ETH","DOGE","crypto_space", "None"],
                                  filter_labels_proportions=[.23,.23,.23,.23,.08])

# %%
# Generate Sentiment Labelling Data for Altcoin Daily 210401 to 210531

folder_path = "D:/nlp_project_d/podcast_data/labelling/batch_1/"
all_file_names = listdir(folder_path)
subtitle_file_paths = []
podcast_names = []

for file_name in all_file_names:
    if file_name[-4:] == ".vtt":
        subtitle_file_paths.append(folder_path + '/' + file_name)
        podcast_names.append(file_name)

prepare_data_for_manual_labelling(subtitle_file_paths,
                                  podcast_names,
                                  "sentiment_labels_altcoin_daily_210401_to_210531.csv",
                                  25,
                                  filter_labels=["BTC","ETH","DOGE","crypto_space", "None"],
                                  filter_labels_proportions=[.23,.23,.23,.23,.08])
# Out:
# Individual word times are not supported for file: D:/nlp_project_d/podcast_data/labelling/batch_1//Altcoin Daily_20210419_BREAKING - Ethereum ETF Approved! United States of America Bitcoin ETF Update! Cryptocurrency News.en.vtt
# Could not generate text chunks for file: D:/nlp_project_d/podcast_data/labelling/batch_1//Altcoin Daily_20210419_BREAKING - Ethereum ETF Approved! United States of America Bitcoin ETF Update! Cryptocurrency News.en.vtt
# Individual word times are not supported for file: D:/nlp_project_d/podcast_data/labelling/batch_1//Altcoin Daily_20210505_Unilayer Platform Review_Walkthrough!_ DeFi in Cryptocurrency GROWING BIGGER!.en.vtt
# Could not generate text chunks for file: D:/nlp_project_d/podcast_data/labelling/batch_1//Altcoin Daily_20210505_Unilayer Platform Review_Walkthrough!_ DeFi in Cryptocurrency GROWING BIGGER!.en.vtt

# %%
# Find sentiment data generation bugs

folder_path = "D:/nlp_project_d/podcast_data/labelling/batch_1/"
subtitle_file_paths = []
podcast_names = []

for file_name in listdir(folder_path):
    if file_name[-4:] == ".vtt":
        subtitle_file_paths.append(folder_path + '/' + file_name)
        podcast_names.append(file_name)


prepare_data_for_manual_labelling([subtitle_file_paths[0]],
                                  [podcast_names[0]],
                                  "sentiment_labels_altcoin_daily_210401.csv",
                                  25)
                                  #filter_labels=["BTC","ETH","DOGE","crypto_space", "None"],
                                  #filter_labels_proportions=[.23,.23,.23,.23,.08])
# Out:
# welcome<00:00:00.560><c> back</c><00:00:00.799><c> everybody</c><00:00:01.360><c> to</c><00:00:01.599><c> altcoin</c><00:00:02.240><c> daily</c>
# ['welcome', 'back', 'everybody', 'to', 'altcoin', 'daily']
# my<00:00:02.960><c> name</c><00:00:03.199><c> is</c>
# ['my', 'name', 'is']
# aaron<00:00:04.480><c> in</c><00:00:04.640><c> today's</c><00:00:05.040><c> video</c><00:00:05.600><c> i</c><00:00:05.759><c> want</c><00:00:05.839><c> to</c><00:00:06.000><c> talk</c>
# ['aaron', 'in', "today's", 'video', 'i', 'want', 'to', 'talk']
# about
# ['about', 'aaron', 'in', "today's", 'video', 'i', 'want', 'to', 'talk']
# ethereum<00:00:08.240><c> versus</c><00:00:09.120><c> bitcoin</c><00:00:09.920><c> can</c>
# ['ethereum', 'versus', 'bitcoin', 'can']
# ethereum<00:00:11.120><c> outperform</c><00:00:12.240><c> bitcoin</c><00:00:13.200><c> before</c><00:00:13.599><c> i</c>
# ['ethereum', 'outperform', 'bitcoin', 'before', 'i']
# play<00:00:14.000><c> you</c><00:00:14.160><c> this</c><00:00:14.400><c> exclusive</c>
# ['play', 'you', 'this', 'exclusive']
# video<00:00:15.759><c> clip</c><00:00:16.080><c> of</c><00:00:16.240><c> notable</c><00:00:16.560><c> bitcoin</c><00:00:17.039><c> only</c>
# ['video', 'clip', 'of', 'notable', 'bitcoin', 'only']
# person<00:00:17.680><c> admitting</c>
# ['person', 'admitting']
# that<00:00:18.880><c> yeah</c><00:00:19.359><c> eth</c><00:00:19.760><c> could</c><00:00:20.080><c> outperform</c><00:00:20.720><c> bitcoin</c>
# ['that', 'yeah', 'eth', 'could', 'outperform', 'bitcoin']
# and<00:00:21.279><c> is</c><00:00:21.359><c> watching</c><00:00:21.680><c> it</c><00:00:21.760><c> very</c><00:00:22.000><c> closely</c>
# ['and', 'is', 'watching', 'it', 'very', 'closely']
# let<00:00:23.359><c> me</c><00:00:23.519><c> preface</c><00:00:23.840><c> this</c><00:00:24.000><c> by</c><00:00:24.240><c> saying</c><00:00:24.480><c> two</c><00:00:24.720><c> things</c>
# ['let', 'me', 'preface', 'this', 'by', 'saying', 'two', 'things']
# number<00:00:25.279><c> one</c><00:00:26.160><c> it</c><00:00:26.400><c> is</c><00:00:26.480><c> not</c>
# ['number', 'one', 'it', 'is', 'not']
# hard<00:00:27.279><c> to</c><00:00:27.439><c> find</c><00:00:27.920><c> an</c><00:00:28.160><c> ethereum</c><00:00:28.800><c> evangelist</c>
# ['hard', 'to', 'find', 'an', 'ethereum', 'evangelist']
# talking<00:00:30.080><c> about</c><00:00:30.400><c> how</c><00:00:30.720><c> eth</c>
# ['talking', 'about', 'how', 'eth']
# can<00:00:31.439><c> outperform</c><00:00:32.079><c> bitcoin</c><00:00:32.559><c> it's</c><00:00:32.640><c> not</c><00:00:32.880><c> hard</c><00:00:33.360><c> to</c>
# ['can', 'outperform', 'bitcoin', "it's", 'not', 'hard', 'to']
# find<00:00:33.760><c> this</c><00:00:34.000><c> opinion</c>
# ['find', 'this', 'opinion']
# an<00:00:34.880><c> eth</c><00:00:35.040><c> evangelist</c><00:00:35.680><c> going</c><00:00:36.000><c> east</c><00:00:36.399><c> is</c><00:00:36.480><c> better</c>
# ['an', 'eth', 'evangelist', 'going', 'east', 'is', 'better']
# than<00:00:36.880><c> bitcoin</c><00:00:37.280><c> this</c><00:00:37.440><c> is</c><00:00:37.520><c> not</c><00:00:37.680><c> a</c><00:00:37.760><c> hard</c><00:00:37.920><c> opinion</c>
# ['than', 'bitcoin', 'this', 'is', 'not', 'a', 'hard', 'opinion']
# to<00:00:38.480><c> find</c>
# ['to', 'find']
# likewise<00:00:40.399><c> it</c><00:00:40.559><c> is</c><00:00:40.640><c> not</c><00:00:40.879><c> hard</c><00:00:41.120><c> to</c><00:00:41.280><c> find</c><00:00:41.520><c> a</c>
# ['likewise', 'it', 'is', 'not', 'hard', 'to', 'find', 'a']
# bitcoin<00:00:42.320><c> evangelist</c><00:00:42.879><c> a</c><00:00:42.960><c> bitcoin</c><00:00:43.440><c> maximalist</c>
# ['bitcoin', 'evangelist', 'a', 'bitcoin', 'maximalist']
# a<00:00:44.239><c> bitcoin</c><00:00:44.800><c> only</c><00:00:45.120><c> person</c>
# ['a', 'bitcoin', 'only', 'person']
# saying<00:00:46.079><c> that</c><00:00:46.320><c> bitcoin</c><00:00:46.879><c> will</c><00:00:47.200><c> outperform</c><00:00:47.840><c> eth</c>
# ['saying', 'that', 'bitcoin', 'will', 'outperform', 'eth']
# and<00:00:48.399><c> bitcoin</c>
# ['and', 'bitcoin']
# is<00:00:49.120><c> better</c><00:00:49.520><c> than</c><00:00:49.840><c> eth</c><00:00:50.399><c> this</c><00:00:50.719><c> is</c><00:00:50.879><c> not</c><00:00:51.120><c> a</c><00:00:51.280><c> hard</c>
# ['is', 'better', 'than', 'eth', 'this', 'is', 'not', 'a', 'hard']
# opinion<00:00:52.000><c> to</c><00:00:52.160><c> find</c>
# ['opinion', 'to', 'find']
# also<00:00:54.000><c> also</c><00:00:54.719><c> today's</c><00:00:55.039><c> video</c><00:00:55.440><c> it's</c><00:00:55.680><c> not</c><00:00:56.000><c> an</c>
# ['also', 'also', "today's", 'video', "it's", 'not', 'an']
# april<00:00:56.559><c> fool's</c><00:00:56.879><c> joke</c><00:00:57.120><c> this</c><00:00:57.360><c> is</c><00:00:57.440><c> not</c><00:00:57.680><c> a</c>
# ['april', "fool's", 'joke', 'this', 'is', 'not', 'a']
# teletubbies<00:00:58.800><c> goof</c><00:00:59.120><c> so</c><00:00:59.359><c> get</c><00:00:59.520><c> that</c><00:00:59.680><c> out</c><00:00:59.840><c> of</c><00:00:59.920><c> your</c>
# ['teletubbies', 'goof', 'so', 'get', 'that', 'out', 'of', 'your']
# head<00:01:00.160><c> right</c><00:01:00.399><c> away</c>
# ['head', 'right', 'away']
# it<00:01:01.760><c> is</c><00:01:02.320><c> a</c><00:01:02.480><c> little</c><00:01:02.719><c> bit</c><00:01:02.960><c> harder</c><00:01:03.359><c> to</c><00:01:03.520><c> find</c><00:01:04.000><c> a</c>
# ['it', 'is', 'a', 'little', 'bit', 'harder', 'to', 'find', 'a']
# bitcoin<00:01:04.720><c> evangelist</c><00:01:05.439><c> a</c><00:01:05.519><c> bitcoin</c><00:01:06.080><c> only</c><00:01:06.320><c> person</c>
# ['bitcoin', 'evangelist', 'a', 'bitcoin', 'only', 'person']
# admitting<00:01:08.080><c> that</c><00:01:08.320><c> ethereum</c><00:01:09.360><c> can</c><00:01:09.840><c> outperform</c>
# ['admitting', 'that', 'ethereum', 'can', 'outperform']
# bitcoin<00:01:11.200><c> and</c><00:01:11.280><c> he</c><00:01:11.439><c> is</c><00:01:11.600><c> watching</c><00:01:12.080><c> it</c>
# ['bitcoin', 'and', 'he', 'is', 'watching', 'it']
# very<00:01:12.960><c> closely</c><00:01:14.240><c> this</c><00:01:14.640><c> is</c><00:01:15.040><c> prominent</c><00:01:15.680><c> bitcoiner</c>
# ['very', 'closely', 'this', 'is', 'prominent', 'bitcoiner']
# nick
# ['nick', 'very', 'closely', 'this', 'is', 'prominent', 'bitcoiner']
# carter<00:01:17.200><c> on</c><00:01:17.439><c> lex</c><00:01:17.840><c> friedman's</c><00:01:18.479><c> podcast</c><00:01:19.360><c> listen</c>
# ['carter', 'on', 'lex', "friedman's", 'podcast', 'listen']
# to<00:01:19.840><c> what</c><00:01:20.000><c> he</c><00:01:20.159><c> says</c>
# ['to', 'what', 'he', 'says']
# then<00:01:21.200><c> we'll</c><00:01:21.360><c> get</c><00:01:21.520><c> into</c><00:01:21.680><c> recent</c><00:01:22.000><c> news</c><00:01:22.320><c> and</c><00:01:22.479><c> also</c>
# ['then', "we'll", 'get', 'into', 'recent', 'news', 'and', 'also']
# i'm<00:01:22.799><c> going</c><00:01:22.960><c> to</c><00:01:23.119><c> clue</c><00:01:23.360><c> you</c><00:01:23.600><c> in</c><00:01:23.759><c> as</c><00:01:23.920><c> to</c><00:01:24.080><c> why</c><00:01:24.400><c> i</c>
# ["i'm", 'going', 'to', 'clue', 'you', 'in', 'as', 'to', 'why', 'i']
# think
# ['think', "i'm", 'going', 'to', 'clue', 'you', 'in', 'as', 'to', 'why', 'i']
# he<00:01:25.360><c> has</c><00:01:25.680><c> a</c><00:01:25.920><c> slightly</c><00:01:26.400><c> more</c><00:01:26.720><c> nuanced</c><00:01:27.360><c> opinion</c>
# ['he', 'has', 'a', 'slightly', 'more', 'nuanced', 'opinion']
# than<00:01:28.560><c> many</c><00:01:28.880><c> bitcoin</c><00:01:29.360><c> maximalists</c><00:01:30.320><c> in</c><00:01:30.400><c> the</c>
# ['than', 'many', 'bitcoin', 'maximalists', 'in', 'the']
# space<00:01:31.200><c> listen</c><00:01:31.520><c> to</c><00:01:31.600><c> this</c>
# ['space', 'listen', 'to', 'this']
# what<00:01:32.079><c> about</c><00:01:32.880><c> bitcoins</c><00:01:33.520><c> comparison</c><00:01:34.159><c> to</c><00:01:34.400><c> other</c>
# ['what', 'about', 'bitcoins', 'comparison', 'to', 'other']
# current<00:01:35.040><c> cryptocurrencies</c><00:01:35.920><c> so</c>
# ['current', 'cryptocurrencies', 'so']
# bitcoin<00:01:36.799><c> versus</c><00:01:37.200><c> ethereum</c><00:01:38.000><c> for</c><00:01:38.240><c> example</c>
# ['bitcoin', 'versus', 'ethereum', 'for', 'example']
# why<00:01:40.159><c> um</c><00:01:41.520><c> is</c><00:01:41.680><c> it</c><00:01:41.759><c> possible</c><00:01:42.159><c> that</c><00:01:42.399><c> ethereum</c>
# ['why', 'um', 'is', 'it', 'possible', 'that', 'ethereum']
# overtakes<00:01:43.439><c> bitcoin</c>
# ['overtakes', 'bitcoin']
# it's<00:01:44.560><c> certainly</c><00:01:44.960><c> possible</c><00:01:45.600><c> yeah</c><00:01:45.759><c> i'm</c><00:01:45.920><c> not</c>
# ["it's", 'certainly', 'possible', 'yeah', "i'm", 'not']
# ruling<00:01:46.399><c> it</c><00:01:46.560><c> out</c><00:01:47.360><c> um</c>
# ['ruling', 'it', 'out', 'um']
# ethereum<00:01:48.799><c> leadership</c><00:01:49.360><c> is</c><00:01:49.439><c> sort</c><00:01:49.600><c> of</c><00:01:49.840><c> wise</c>
# ['ethereum', 'leadership', 'is', 'sort', 'of', 'wise']
# enough<00:01:50.560><c> to</c><00:01:50.799><c> understand</c>
# ['enough', 'to', 'understand']
# that<00:01:52.079><c> they</c><00:01:52.479><c> shouldn't</c><00:01:52.880><c> compete</c><00:01:53.200><c> with</c><00:01:53.360><c> bitcoin</c>
# ['that', 'they', "shouldn't", 'compete', 'with', 'bitcoin']
# on<00:01:54.640><c> those</c>
# ['on', 'those']
# most<00:01:55.439><c> profound</c><00:01:56.960><c> qualities</c><00:01:57.840><c> like</c><00:01:58.079><c> ethereum</c>
# ['most', 'profound', 'qualities', 'like', 'ethereum']
# doesn't<00:01:58.960><c> really</c><00:01:59.280><c> aspire</c><00:01:59.759><c> to</c><00:01:59.920><c> be</c>
# ["doesn't", 'really', 'aspire', 'to', 'be']
# more<00:02:01.280><c> um</c><00:02:01.920><c> sound</c><00:02:02.320><c> from</c><00:02:02.560><c> a</c><00:02:02.640><c> monetary</c>
# ['more', 'um', 'sound', 'from', 'a', 'monetary']
# perspective<00:02:03.759><c> than</c><00:02:03.920><c> bitcoin</c>
# ['perspective', 'than', 'bitcoin']
# right<00:02:05.119><c> the</c><00:02:05.280><c> in</c><00:02:05.439><c> fact</c><00:02:05.600><c> the</c><00:02:05.680><c> ethereum</c>
# ['right', 'the', 'in', 'fact', 'the', 'ethereum']
# leadership<00:02:06.479><c> are</c><00:02:06.640><c> sort</c><00:02:06.799><c> of</c><00:02:06.880><c> constantly</c>
# ['leadership', 'are', 'sort', 'of', 'constantly']
# tweaking<00:02:07.840><c> the</c><00:02:07.920><c> monetary</c><00:02:08.479><c> policy</c>
# ['tweaking', 'the', 'monetary', 'policy']
# so<00:02:10.239><c> they</c><00:02:10.399><c> went</c><00:02:10.640><c> for</c><00:02:10.800><c> a</c><00:02:10.879><c> completely</c><00:02:11.280><c> different</c>
# ['so', 'they', 'went', 'for', 'a', 'completely', 'different']
# trade-off<00:02:12.160><c> right</c>
# ['trade-off', 'right']
# they<00:02:13.520><c> also</c><00:02:13.760><c> don't</c><00:02:14.080><c> compete</c><00:02:14.720><c> to</c><00:02:14.879><c> be</c><00:02:15.599><c> as</c>
# ['they', 'also', "don't", 'compete', 'to', 'be', 'as']
# decentralized<00:02:16.959><c> from</c><00:02:17.120><c> a</c><00:02:17.200><c> governance</c>
# ['decentralized', 'from', 'a', 'governance']
# perspective<00:02:18.400><c> right</c>
# ['perspective', 'right']
# because<00:02:19.040><c> there's</c><00:02:19.360><c> leadership</c><00:02:20.000><c> there's</c><00:02:20.239><c> an</c>
# ['because', "there's", 'leadership', "there's", 'an']
# eth<00:02:20.640><c> foundation</c><00:02:21.760><c> there's</c><00:02:22.000><c> a</c><00:02:22.160><c> charismatic</c>
# ['eth', 'foundation', "there's", 'a', 'charismatic']
# leader<00:02:23.040><c> of</c><00:02:23.120><c> italic</c>
# ['leader', 'of', 'italic']
# and<00:02:25.200><c> ethereum</c><00:02:25.760><c> has</c><00:02:26.000><c> this</c><00:02:26.239><c> policy</c><00:02:26.640><c> of</c><00:02:26.800><c> hard</c>
# ['and', 'ethereum', 'has', 'this', 'policy', 'of', 'hard']
# forks
# ['forks', 'and', 'ethereum', 'has', 'this', 'policy', 'of', 'hard']
# so<00:02:28.560><c> in</c><00:02:28.720><c> bitcoin</c><00:02:29.200><c> hard</c><00:02:29.360><c> forks</c><00:02:29.680><c> are</c><00:02:29.760><c> extremely</c>
# ['so', 'in', 'bitcoin', 'hard', 'forks', 'are', 'extremely']
# rare
# ['rare', 'so', 'in', 'bitcoin', 'hard', 'forks', 'are', 'extremely']
# in<00:02:31.280><c> ethereum</c><00:02:32.000><c> it's</c><00:02:32.160><c> the</c><00:02:32.319><c> default</c><00:02:32.640><c> way</c><00:02:32.800><c> to</c>
# ['in', 'ethereum', "it's", 'the', 'default', 'way', 'to']
# change<00:02:33.280><c> things</c><00:02:34.000><c> so</c><00:02:34.160><c> it's</c><00:02:34.400><c> a</c><00:02:34.480><c> much</c>
# ['change', 'things', 'so', "it's", 'a', 'much']
# more<00:02:35.200><c> adaptive</c><00:02:35.840><c> system</c><00:02:36.560><c> and</c><00:02:36.800><c> it</c><00:02:36.879><c> changes</c><00:02:37.360><c> more</c>
# ['more', 'adaptive', 'system', 'and', 'it', 'changes', 'more']
# frequently
# ['frequently', 'more', 'adaptive', 'system', 'and', 'it', 'changes', 'more']
# but<00:02:38.640><c> that</c><00:02:38.879><c> also</c><00:02:39.120><c> means</c><00:02:39.360><c> that</c><00:02:39.519><c> it's</c><00:02:40.400><c> sort</c><00:02:40.640><c> of</c>
# ['but', 'that', 'also', 'means', 'that', "it's", 'sort', 'of']
# they're<00:02:40.959><c> incurring</c><00:02:41.280><c> more</c><00:02:41.519><c> risk</c>
# ["they're", 'incurring', 'more', 'risk']
# when<00:02:42.319><c> they</c><00:02:42.879><c> introduce</c><00:02:43.280><c> those</c><00:02:43.519><c> changes</c>
# ['when', 'they', 'introduce', 'those', 'changes']
# there's<00:02:44.160><c> much</c><00:02:44.319><c> more</c><00:02:44.480><c> complexity</c><00:02:45.120><c> so</c>
# ["there's", 'much', 'more', 'complexity', 'so']
# ethereum<00:02:47.280><c> is</c><00:02:47.440><c> smart</c><00:02:48.080><c> because</c><00:02:48.560><c> they</c><00:02:48.720><c> sort</c><00:02:48.879><c> of</c>
# ['ethereum', 'is', 'smart', 'because', 'they', 'sort', 'of']
# understood<00:02:49.519><c> bitcoin</c>
# ['understood', 'bitcoin']
# as<00:02:50.160><c> the</c><00:02:50.239><c> top</c><00:02:50.480><c> dog</c><00:02:50.800><c> when</c><00:02:50.959><c> it</c><00:02:51.040><c> comes</c><00:02:51.280><c> to</c><00:02:51.519><c> a</c><00:02:51.680><c> sound</c>
# ['as', 'the', 'top', 'dog', 'when', 'it', 'comes', 'to', 'a', 'sound']
# money
# ['money', 'as', 'the', 'top', 'dog', 'when', 'it', 'comes', 'to', 'a', 'sound']
# a<00:02:53.599><c> digital</c><00:02:54.080><c> gold</c><00:02:54.640><c> type</c><00:02:54.959><c> thing</c><00:02:55.760><c> and</c><00:02:55.840><c> they</c><00:02:56.080><c> went</c>
# ['a', 'digital', 'gold', 'type', 'thing', 'and', 'they', 'went']
# for<00:02:56.480><c> all</c><00:02:56.640><c> of</c><00:02:56.800><c> the</c><00:02:56.879><c> different</c><00:02:57.120><c> trade-offs</c>
# ['for', 'all', 'of', 'the', 'different', 'trade-offs']
# they<00:02:58.720><c> wanted</c><00:02:59.040><c> to</c><00:02:59.200><c> be</c><00:02:59.920><c> more</c><00:03:00.080><c> of</c><00:03:00.239><c> a</c><00:03:00.400><c> platform</c>
# ['they', 'wanted', 'to', 'be', 'more', 'of', 'a', 'platform']
# they<00:03:01.680><c> wanted</c><00:03:01.920><c> to</c><00:03:02.000><c> have</c><00:03:02.159><c> more</c><00:03:02.400><c> complexity</c><00:03:03.120><c> the</c>
# ['they', 'wanted', 'to', 'have', 'more', 'complexity', 'the']
# transactional<00:03:04.000><c> layer</c>
# ['transactional', 'layer']
# they<00:03:05.120><c> wanted</c><00:03:05.519><c> to</c><00:03:06.000><c> take</c><00:03:06.239><c> on</c><00:03:06.400><c> more</c><00:03:06.640><c> risk</c><00:03:06.959><c> in</c>
# ['they', 'wanted', 'to', 'take', 'on', 'more', 'risk', 'in']
# terms<00:03:07.280><c> of</c><00:03:07.440><c> changing</c><00:03:07.760><c> the</c><00:03:07.920><c> protocol</c><00:03:08.480><c> they</c>
# ['terms', 'of', 'changing', 'the', 'protocol', 'they']
# wanted<00:03:08.959><c> to</c><00:03:09.120><c> change</c><00:03:09.440><c> more</c><00:03:09.680><c> quickly</c>
# ['wanted', 'to', 'change', 'more', 'quickly']
# they<00:03:11.120><c> wanted</c><00:03:11.360><c> to</c><00:03:11.760><c> make</c><00:03:12.000><c> the</c><00:03:12.159><c> monetary</c><00:03:12.640><c> policy</c>
# ['they', 'wanted', 'to', 'make', 'the', 'monetary', 'policy']
# more<00:03:13.280><c> mutable</c>
# ['more', 'mutable']
# so<00:03:15.840><c> ethereum</c><00:03:16.879><c> takes</c><00:03:17.200><c> that</c><00:03:17.360><c> completely</c>
# ['so', 'ethereum', 'takes', 'that', 'completely']
# different
# ['different', 'so', 'ethereum', 'takes', 'that', 'completely']
# tack<00:03:18.480><c> of</c><00:03:18.560><c> course</c><00:03:19.120><c> you</c><00:03:19.200><c> know</c><00:03:19.360><c> i'm</c><00:03:19.440><c> not</c><00:03:19.680><c> ruling</c>
# ['tack', 'of', 'course', 'you', 'know', "i'm", 'not', 'ruling']
# out<00:03:20.080><c> that</c><00:03:20.239><c> it</c><00:03:20.319><c> could</c><00:03:20.480><c> take</c><00:03:20.720><c> over</c><00:03:20.959><c> bitcoin</c>
# ['out', 'that', 'it', 'could', 'take', 'over', 'bitcoin']
# from<00:03:22.239><c> a</c><00:03:22.319><c> market</c><00:03:22.640><c> cap</c><00:03:22.879><c> perspective</c><00:03:24.159><c> it's</c><00:03:24.319><c> just</c>
# ['from', 'a', 'market', 'cap', 'perspective', "it's", 'just']
# a<00:03:24.640><c> very</c><00:03:24.799><c> different</c><00:03:25.200><c> system</c>
# ['a', 'very', 'different', 'system']
# and<00:03:27.120><c> i</c><00:03:27.440><c> tend</c><00:03:27.599><c> to</c><00:03:27.760><c> think</c><00:03:27.920><c> the</c><00:03:28.000><c> bitcoin</c><00:03:28.400><c> is</c><00:03:28.560><c> the</c>
# ['and', 'i', 'tend', 'to', 'think', 'the', 'bitcoin', 'is', 'the']
# most<00:03:28.799><c> disruptive</c><00:03:29.519><c> one</c>
# ['most', 'disruptive', 'one']
# because<00:03:30.400><c> it's</c><00:03:30.720><c> the</c><00:03:30.879><c> most</c><00:03:31.200><c> equipped</c><00:03:31.840><c> to</c>
# ['because', "it's", 'the', 'most', 'equipped', 'to']
# challenge
# ['challenge', 'because', "it's", 'the', 'most', 'equipped', 'to']
# sovereign<00:03:33.680><c> currencies</c><00:03:34.319><c> in</c><00:03:34.400><c> the</c><00:03:34.560><c> grand</c><00:03:34.799><c> scheme</c>
# ['sovereign', 'currencies', 'in', 'the', 'grand', 'scheme']
# do<00:03:35.519><c> you</c><00:03:35.599><c> think</c><00:03:35.760><c> they</c><00:03:36.000><c> can</c>
# ['do', 'you', 'think', 'they', 'can']
# co-exist<00:03:38.319><c> so</c><00:03:38.480><c> like</c><00:03:38.720><c> in</c><00:03:38.799><c> the</c><00:03:38.959><c> future</c>
# ['co-exist', 'so', 'like', 'in', 'the', 'future']
# is<00:03:40.319><c> do</c><00:03:40.480><c> you</c><00:03:40.560><c> see</c><00:03:40.799><c> a</c><00:03:40.959><c> world</c><00:03:41.360><c> where</c><00:03:42.879><c> you</c><00:03:42.959><c> know</c>
# ['is', 'do', 'you', 'see', 'a', 'world', 'where', 'you', 'know']
# uh<00:03:43.920><c> ethereum</c><00:03:45.360><c> captures</c><00:03:46.000><c> some</c><00:03:46.319><c> large</c><00:03:46.640><c> percent</c>
# ['uh', 'ethereum', 'captures', 'some', 'large', 'percent']
# of<00:03:47.120><c> the</c><00:03:47.200><c> market</c>
# ['of', 'the', 'market']
# and<00:03:48.640><c> but</c><00:03:48.879><c> nevertheless</c><00:03:49.440><c> the</c><00:03:49.599><c> minority</c>
# ['and', 'but', 'nevertheless', 'the', 'minority']
# a<00:03:51.280><c> hundred</c><00:03:51.680><c> percent</c><00:03:52.239><c> 100</c><00:03:52.640><c> percent</c><00:03:53.519><c> bitcoin</c>
# ['a', 'hundred', 'percent', '100', 'percent', 'bitcoin']
# has<00:03:54.239><c> already</c><00:03:54.640><c> been</c><00:03:54.879><c> tokenized</c><00:03:55.680><c> and</c><00:03:55.920><c> put</c><00:03:56.239><c> on</c><00:03:56.400><c> to</c>
# ['has', 'already', 'been', 'tokenized', 'and', 'put', 'on', 'to']
# ethereum
# ['ethereum', 'has', 'already', 'been', 'tokenized', 'and', 'put', 'on', 'to']
# many<00:03:57.920><c> units</c><00:03:58.239><c> of</c><00:03:58.319><c> bitcoin</c><00:03:58.799><c> i</c><00:03:58.879><c> think</c><00:03:59.040><c> over</c><00:03:59.200><c> a</c>
# ['many', 'units', 'of', 'bitcoin', 'i', 'think', 'over', 'a']
# billion<00:03:59.680><c> dollars</c><00:04:00.080><c> worth</c>
# ['billion', 'dollars', 'worth']
# so<00:04:01.760><c> not</c><00:04:02.000><c> only</c><00:04:02.239><c> do</c><00:04:02.400><c> they</c><00:04:02.560><c> coexist</c><00:04:03.280><c> they</c><00:04:03.439><c> are</c>
# ['so', 'not', 'only', 'do', 'they', 'coexist', 'they', 'are']
# actually<00:04:03.920><c> mutualistic</c>
# ['actually', 'mutualistic']
# so<00:04:05.760><c> they're</c><00:04:06.000><c> like</c><00:04:06.239><c> two</c><00:04:06.480><c> creatures</c><00:04:07.120><c> that</c><00:04:07.360><c> have</c>
# ['so', "they're", 'like', 'two', 'creatures', 'that', 'have']
# this<00:04:08.480><c> you</c><00:04:08.560><c> know</c><00:04:08.799><c> it's</c><00:04:08.959><c> like</c><00:04:09.200><c> the</c>
# ['this', 'you', 'know', "it's", 'like', 'the']
# the<00:04:10.560><c> rhino</c><00:04:11.200><c> and</c><00:04:11.360><c> like</c><00:04:11.680><c> the</c><00:04:11.840><c> bird</c><00:04:12.159><c> the</c><00:04:12.319><c> pecks</c>
# ['the', 'rhino', 'and', 'like', 'the', 'bird', 'the', 'pecks']
# the<00:04:12.720><c> parasites</c><00:04:13.439><c> off</c><00:04:13.599><c> the</c><00:04:13.760><c> rhino's</c><00:04:14.239><c> back</c><00:04:14.480><c> or</c>
# ['the', 'parasites', 'off', 'the', "rhino's", 'back', 'or']
# whatever
# ['whatever', 'the', 'parasites', 'off', 'the', "rhino's", 'back', 'or']
# yeah<00:04:15.599><c> right</c><00:04:15.920><c> so</c><00:04:16.400><c> i</c><00:04:16.560><c> don't</c><00:04:16.639><c> know</c><00:04:16.799><c> which</c><00:04:17.040><c> is</c>
# ['yeah', 'right', 'so', 'i', "don't", 'know', 'which', 'is']
# which<00:04:17.440><c> in</c><00:04:17.519><c> the</c><00:04:17.600><c> analogy</c>
# ['which', 'in', 'the', 'analogy']
# but<00:04:19.040><c> yeah</c><00:04:19.199><c> i</c><00:04:19.280><c> don't</c><00:04:19.359><c> know</c><00:04:19.440><c> who</c><00:04:19.600><c> the</c><00:04:19.759><c> parasites</c>
# ['but', 'yeah', 'i', "don't", 'know', 'who', 'the', 'parasites']
# are
# ['are', 'but', 'yeah', 'i', "don't", 'know', 'who', 'the', 'parasites']
# yellow<00:04:23.360><c> or</c><00:04:23.759><c> you</c><00:04:23.840><c> know</c><00:04:24.320><c> the</c><00:04:24.479><c> alligator</c><00:04:25.120><c> and</c><00:04:25.440><c> the</c>
# ['yellow', 'or', 'you', 'know', 'the', 'alligator', 'and', 'the']
# teeth<00:04:26.080><c> cleaning</c><00:04:26.479><c> fish</c><00:04:26.800><c> or</c><00:04:26.960><c> whatever</c><00:04:27.360><c> right</c><00:04:27.840><c> so</c>
# ['teeth', 'cleaning', 'fish', 'or', 'whatever', 'right', 'so']
# oh<00:04:28.479><c> you</c><00:04:28.560><c> know</c><00:04:28.720><c> i</c><00:04:28.800><c> always</c><00:04:29.040><c> wonder</c><00:04:29.360><c> why</c><00:04:29.520><c> the</c>
# ['oh', 'you', 'know', 'i', 'always', 'wonder', 'why', 'the']
# alligator<00:04:30.080><c> doesn't</c><00:04:30.400><c> just</c>
# ['alligator', "doesn't", 'just']
# eat<00:04:31.040><c> the</c><00:04:31.199><c> fish</c><00:04:31.680><c> but</c><00:04:32.000><c> uh</c><00:04:32.639><c> i</c><00:04:32.720><c> guess</c><00:04:32.960><c> they're</c>
# ['eat', 'the', 'fish', 'but', 'uh', 'i', 'guess', "they're"]
# brushing<00:04:33.600><c> its</c><00:04:33.759><c> teeth</c><00:04:34.080><c> basically</c><00:04:34.639><c> so</c>
# ['brushing', 'its', 'teeth', 'basically', 'so']
# um<00:04:36.720><c> ethereum</c><00:04:37.600><c> is</c><00:04:38.160><c> it</c><00:04:38.240><c> gives</c><00:04:38.479><c> you</c><00:04:38.560><c> more</c>
# ['um', 'ethereum', 'is', 'it', 'gives', 'you', 'more']
# transactional<00:04:39.360><c> flexibility</c><00:04:40.000><c> there's</c><00:04:40.400><c> much</c>
# ['transactional', 'flexibility', "there's", 'much']
# more<00:04:40.880><c> experimentation</c><00:04:41.759><c> happening</c><00:04:42.160><c> there</c>
# ['more', 'experimentation', 'happening', 'there']
# it<00:04:43.040><c> has</c><00:04:43.280><c> this</c><00:04:43.360><c> whole</c><00:04:43.520><c> decentralized</c><00:04:44.240><c> finance</c>
# ['it', 'has', 'this', 'whole', 'decentralized', 'finance']
# element
# ['element', 'it', 'has', 'this', 'whole', 'decentralized', 'finance']
# there's<00:04:46.479><c> a</c><00:04:46.560><c> huge</c><00:04:46.720><c> number</c><00:04:46.960><c> of</c><00:04:47.040><c> bitcoins</c><00:04:47.600><c> that</c>
# ["there's", 'a', 'huge', 'number', 'of', 'bitcoins', 'that']
# circulate<00:04:48.639><c> on</c><00:04:48.960><c> the</c><00:04:49.120><c> ethereum</c><00:04:49.520><c> protocol</c>
# ['circulate', 'on', 'the', 'ethereum', 'protocol']
# right<00:04:50.400><c> because</c><00:04:50.639><c> ethereum</c><00:04:51.680><c> is</c><00:04:51.840><c> open</c><00:04:52.160><c> to</c><00:04:52.320><c> other</c>
# ['right', 'because', 'ethereum', 'is', 'open', 'to', 'other']
# asset<00:04:53.040><c> types</c><00:04:53.520><c> basically</c>
# ['asset', 'types', 'basically']
# so<00:04:55.440><c> i</c><00:04:55.520><c> think</c><00:04:55.680><c> that's</c><00:04:56.000><c> actually</c><00:04:56.400><c> accretive</c><00:04:56.960><c> to</c>
# ['so', 'i', 'think', "that's", 'actually', 'accretive', 'to']
# both<00:04:57.440><c> systems</c>
# ['both', 'systems']
# because<00:04:59.040><c> ethereum</c><00:04:59.520><c> gets</c><00:04:59.759><c> to</c><00:04:59.840><c> have</c><00:05:00.080><c> this</c><00:05:00.240><c> good</c>
# ['because', 'ethereum', 'gets', 'to', 'have', 'this', 'good']
# form<00:05:00.720><c> of</c><00:05:00.880><c> collateral</c><00:05:01.520><c> bitcoin</c>
# ['form', 'of', 'collateral', 'bitcoin']
# on<00:05:02.479><c> the</c><00:05:02.560><c> system</c><00:05:03.600><c> which</c><00:05:03.759><c> is</c><00:05:03.919><c> good</c><00:05:04.160><c> volatility</c>
# ['on', 'the', 'system', 'which', 'is', 'good', 'volatility']
# characteristics
# ['characteristics', 'on', 'the', 'system', 'which', 'is', 'good', 'volatility']
# and<00:05:06.320><c> then</c><00:05:06.960><c> it's</c><00:05:07.199><c> a</c><00:05:07.280><c> supply</c><00:05:07.919><c> sync</c><00:05:08.479><c> for</c><00:05:08.639><c> bitcoins</c>
# ['and', 'then', "it's", 'a', 'supply', 'sync', 'for', 'bitcoins']
# which<00:05:10.000><c> are</c><00:05:10.160><c> sort</c><00:05:10.320><c> of</c><00:05:11.039><c> now</c><00:05:11.280><c> they're</c><00:05:11.840><c> injected</c>
# ['which', 'are', 'sort', 'of', 'now', "they're", 'injected']
# into<00:05:12.720><c> this</c><00:05:12.880><c> third-party</c><00:05:13.440><c> protocol</c>
# ['into', 'this', 'third-party', 'protocol']
# and<00:05:14.720><c> that</c><00:05:15.440><c> i</c><00:05:15.520><c> think</c><00:05:16.320><c> reduces</c><00:05:16.880><c> the</c><00:05:17.039><c> velocity</c><00:05:17.600><c> of</c>
# ['and', 'that', 'i', 'think', 'reduces', 'the', 'velocity', 'of']
# bitcoin<00:05:18.080><c> overall</c><00:05:18.479><c> and</c><00:05:18.560><c> it's</c><00:05:18.720><c> probably</c><00:05:18.960><c> good</c>
# ['bitcoin', 'overall', 'and', "it's", 'probably', 'good']
# for<00:05:19.360><c> the</c><00:05:19.440><c> valuation</c>
# ['for', 'the', 'valuation']
# so<00:05:21.199><c> you</c><00:05:21.360><c> see</c><00:05:21.600><c> it</c><00:05:22.160><c> it</c><00:05:22.320><c> quite</c><00:05:22.560><c> possibly</c><00:05:22.880><c> could</c><00:05:23.039><c> be</c>
# ['so', 'you', 'see', 'it', 'it', 'quite', 'possibly', 'could', 'be']
# a<00:05:23.360><c> symbiotic</c><00:05:24.000><c> relationship</c><00:05:24.639><c> that's</c><00:05:24.880><c> really</c>
# ['a', 'symbiotic', 'relationship', "that's", 'really']
# interesting
# ['interesting', 'a', 'symbiotic', 'relationship', "that's", 'really']
# i<00:05:25.840><c> think</c><00:05:26.080><c> so</c><00:05:26.479><c> i</c><00:05:26.639><c> think</c><00:05:26.800><c> so</c><00:05:27.440><c> it</c><00:05:27.840><c> is</c><00:05:28.479><c> refreshing</c>
# ['i', 'think', 'so', 'i', 'think', 'so', 'it', 'is', 'refreshing']
# to<00:05:29.440><c> me</c><00:05:29.680><c> to</c><00:05:29.840><c> hear</c><00:05:30.080><c> a</c><00:05:30.240><c> bitcoin</c><00:05:30.800><c> only</c><00:05:31.199><c> person</c>
# ['to', 'me', 'to', 'hear', 'a', 'bitcoin', 'only', 'person']
# speak<00:05:32.639><c> more</c><00:05:32.880><c> thoughtfully</c><00:05:33.440><c> and</c><00:05:33.600><c> nuanced</c>
# ['speak', 'more', 'thoughtfully', 'and', 'nuanced']
# about<00:05:34.400><c> this</c><00:05:34.639><c> space</c><00:05:35.039><c> you</c><00:05:35.120><c> know</c><00:05:35.280><c> we</c><00:05:35.440><c> hear</c>
# ['about', 'this', 'space', 'you', 'know', 'we', 'hear']
# all<00:05:36.080><c> the</c><00:05:36.320><c> time</c><00:05:36.880><c> opinions</c><00:05:37.440><c> like</c><00:05:37.759><c> this</c><00:05:38.320><c> echoed</c>
# ['all', 'the', 'time', 'opinions', 'like', 'this', 'echoed']
# in<00:05:38.960><c> the</c><00:05:39.120><c> choir</c><00:05:39.520><c> of</c><00:05:39.600><c> bitcoin</c><00:05:40.080><c> twitter</c>
# ['in', 'the', 'choir', 'of', 'bitcoin', 'twitter']
# so<00:05:41.520><c> when</c><00:05:41.680><c> somebody</c><00:05:42.000><c> like</c><00:05:42.240><c> nick</c><00:05:42.479><c> carter</c><00:05:42.800><c> comes</c>
# ['so', 'when', 'somebody', 'like', 'nick', 'carter', 'comes']
# out<00:05:43.199><c> with</c><00:05:43.360><c> more</c><00:05:43.520><c> thoughtful</c><00:05:43.840><c> opinion</c>
# ['out', 'with', 'more', 'thoughtful', 'opinion']
# i<00:05:44.720><c> tend</c><00:05:45.120><c> to</c><00:05:45.360><c> listen</c><00:05:45.680><c> now</c><00:05:46.560><c> my</c><00:05:46.800><c> speculation</c>
# ['i', 'tend', 'to', 'listen', 'now', 'my', 'speculation']
# as<00:05:48.080><c> to</c><00:05:48.240><c> why</c><00:05:49.039><c> nick</c><00:05:49.680><c> has</c><00:05:50.000><c> a</c><00:05:50.240><c> more</c><00:05:50.720><c> nuanced</c>
# ['as', 'to', 'why', 'nick', 'has', 'a', 'more', 'nuanced']
# opinion<00:05:51.840><c> than</c><00:05:52.080><c> a</c><00:05:52.160><c> lot</c><00:05:52.479><c> of</c><00:05:52.639><c> opinions</c><00:05:53.120><c> i</c><00:05:53.280><c> see</c>
# ['opinion', 'than', 'a', 'lot', 'of', 'opinions', 'i', 'see']
# on<00:05:53.759><c> bitcoin</c><00:05:54.240><c> twitter</c><00:05:54.960><c> it's</c><00:05:55.199><c> probably</c><00:05:55.919><c> because</c>
# ['on', 'bitcoin', 'twitter', "it's", 'probably', 'because']
# he<00:05:56.720><c> is</c><00:05:56.880><c> the</c><00:05:57.199><c> founder</c>
# ['he', 'is', 'the', 'founder']
# or<00:05:58.000><c> leadership</c><00:05:58.639><c> at</c><00:05:58.880><c> coinmetrics</c><00:06:00.000><c> which</c><00:06:00.240><c> is</c>
# ['or', 'leadership', 'at', 'coinmetrics', 'which', 'is']
# basically<00:06:00.800><c> a</c><00:06:00.960><c> crypto</c><00:06:01.600><c> asset</c>
# ['basically', 'a', 'crypto', 'asset']
# analytics<00:06:03.199><c> research</c><00:06:03.919><c> data</c><00:06:04.319><c> center</c><00:06:05.120><c> so</c><00:06:05.360><c> he's</c>
# ['analytics', 'research', 'data', 'center', 'so', "he's"]
# constantly<00:06:06.160><c> looking</c><00:06:06.479><c> at</c><00:06:06.560><c> the</c><00:06:06.720><c> data</c><00:06:07.120><c> for</c>
# ['constantly', 'looking', 'at', 'the', 'data', 'for']
# bitcoin<00:06:07.840><c> ethereum</c>
# ['bitcoin', 'ethereum']
# and<00:06:09.199><c> all</c><00:06:09.520><c> of</c><00:06:09.680><c> the</c><00:06:09.840><c> leading</c><00:06:10.319><c> cryptocurrency</c>
# ['and', 'all', 'of', 'the', 'leading', 'cryptocurrency']
# assets
# ['assets', 'and', 'all', 'of', 'the', 'leading', 'cryptocurrency']
# so<00:06:12.319><c> he's</c><00:06:12.639><c> not</c><00:06:12.960><c> in</c><00:06:13.120><c> the</c><00:06:13.280><c> dark</c><00:06:13.680><c> about</c><00:06:14.000><c> ethereum's</c>
# ['so', "he's", 'not', 'in', 'the', 'dark', 'about', "ethereum's"]
# network<00:06:14.960><c> effect</c><00:06:15.280><c> or</c><00:06:15.440><c> ethereum's</c><00:06:15.919><c> growth</c>
# ['network', 'effect', 'or', "ethereum's", 'growth']
# or<00:06:17.120><c> even</c><00:06:17.680><c> ethereum's</c><00:06:18.639><c> scaling</c><00:06:19.360><c> solutions</c>
# ['or', 'even', "ethereum's", 'scaling', 'solutions']
# so<00:06:20.960><c> let's</c><00:06:21.280><c> actually</c><00:06:21.680><c> get</c><00:06:22.080><c> into</c><00:06:22.319><c> this</c><00:06:22.560><c> i</c><00:06:22.720><c> want</c>
# ['so', "let's", 'actually', 'get', 'into', 'this', 'i', 'want']
# to<00:06:22.880><c> talk</c><00:06:23.120><c> about</c><00:06:23.280><c> bitcoin</c><00:06:23.840><c> in</c><00:06:23.919><c> just</c><00:06:24.160><c> a</c><00:06:24.240><c> second</c>
# ['to', 'talk', 'about', 'bitcoin', 'in', 'just', 'a', 'second']
# but<00:06:24.800><c> let's</c>
# ['but', "let's"]
# actually<00:06:25.840><c> talk</c><00:06:26.160><c> about</c><00:06:26.720><c> why</c><00:06:27.039><c> ethereum</c>
# ['actually', 'talk', 'about', 'why', 'ethereum']
# is<00:06:28.479><c> really</c><00:06:28.880><c> different</c><00:06:29.360><c> from</c><00:06:29.520><c> the</c><00:06:29.600><c> ethereum</c>
# ['is', 'really', 'different', 'from', 'the', 'ethereum']
# that<00:06:30.240><c> we</c><00:06:30.400><c> knew</c><00:06:30.800><c> two</c><00:06:31.039><c> years</c><00:06:31.280><c> ago</c>
# ['that', 'we', 'knew', 'two', 'years', 'ago']
# four<00:06:32.000><c> years</c><00:06:32.240><c> ago</c><00:06:33.280><c> there</c><00:06:33.520><c> is</c><00:06:33.680><c> plenty</c><00:06:34.240><c> of</c><00:06:34.479><c> layer</c>
# ['four', 'years', 'ago', 'there', 'is', 'plenty', 'of', 'layer']
# two
# ['two', 'four', 'years', 'ago', 'there', 'is', 'plenty', 'of', 'layer']
# scaling<00:06:35.840><c> solutions</c><00:06:36.400><c> that</c><00:06:36.560><c> are</c><00:06:36.720><c> either</c><00:06:37.039><c> here</c>
# ['scaling', 'solutions', 'that', 'are', 'either', 'here']
# or<00:06:37.520><c> coming</c><00:06:37.840><c> out</c><00:06:38.240><c> this</c><00:06:38.479><c> year</c>
# ['or', 'coming', 'out', 'this', 'year']
# for<00:06:39.440><c> instance</c><00:06:39.840><c> immutable</c><00:06:40.400><c> x</c><00:06:40.960><c> nft</c><00:06:41.919><c> marketplace</c>
# ['for', 'instance', 'immutable', 'x', 'nft', 'marketplace']
# open<00:06:43.199><c> c</c><00:06:43.600><c> which</c><00:06:43.759><c> is</c><00:06:43.919><c> an</c><00:06:44.080><c> ethereum</c><00:06:44.479><c> based</c><00:06:44.800><c> nft</c>
# ['open', 'c', 'which', 'is', 'an', 'ethereum', 'based', 'nft']
# marketplace
# ['marketplace', 'open', 'c', 'which', 'is', 'an', 'ethereum', 'based', 'nft']
# plans<00:06:46.800><c> to</c><00:06:46.960><c> integrate</c><00:06:47.680><c> layer</c><00:06:48.000><c> 2</c><00:06:48.319><c> protocol</c>
# ['plans', 'to', 'integrate', 'layer', '2', 'protocol']
# immutable
# ['immutable', 'plans', 'to', 'integrate', 'layer', '2', 'protocol']
# x<00:06:50.960><c> now</c><00:06:51.199><c> if</c><00:06:51.280><c> you've</c><00:06:51.520><c> been</c><00:06:51.680><c> subscribed</c><00:06:52.080><c> to</c><00:06:52.240><c> the</c>
# ['x', 'now', 'if', "you've", 'been', 'subscribed', 'to', 'the']
# channel<00:06:52.639><c> you've</c><00:06:52.800><c> heard</c><00:06:52.960><c> about</c><00:06:53.120><c> immutablex</c>
# ['channel', "you've", 'heard', 'about', 'immutablex']
# before
# ['before', 'channel', "you've", 'heard', 'about', 'immutablex']
# gods<00:06:55.440><c> unchained</c><00:06:56.319><c> which</c><00:06:56.560><c> is</c><00:06:56.720><c> a</c><00:06:56.800><c> company</c><00:06:57.120><c> we</c>
# ['gods', 'unchained', 'which', 'is', 'a', 'company', 'we']
# worked<00:06:57.520><c> with</c>
# ['worked', 'with']
# uses<00:06:58.400><c> immutablex</c><00:06:59.280><c> for</c><00:06:59.520><c> their</c><00:06:59.759><c> nft</c><00:07:00.400><c> and</c>
# ['uses', 'immutablex', 'for', 'their', 'nft', 'and']
# gameplay<00:07:01.039><c> it's</c><00:07:01.199><c> also</c><00:07:01.440><c> built</c><00:07:01.680><c> on</c><00:07:01.840><c> ethereum</c>
# ['gameplay', "it's", 'also', 'built', 'on', 'ethereum']
# anyways<00:07:02.960><c> according</c><00:07:03.360><c> to</c><00:07:03.520><c> the</c><00:07:03.680><c> press</c><00:07:04.160><c> statement</c>
# ['anyways', 'according', 'to', 'the', 'press', 'statement']
# integrating<00:07:05.199><c> immutable</c><00:07:05.680><c> x</c><00:07:05.840><c> will</c><00:07:06.000><c> allow</c><00:07:06.160><c> the</c>
# ['integrating', 'immutable', 'x', 'will', 'allow', 'the']
# marketplace<00:07:06.880><c> to</c><00:07:07.039><c> offer</c>
# ['marketplace', 'to', 'offer']
# openc<00:07:08.160><c> users</c><00:07:09.120><c> gas-free</c><00:07:10.319><c> trading</c><00:07:10.800><c> experience</c>
# ['openc', 'users', 'gas-free', 'trading', 'experience']
# without<00:07:11.680><c> sacrificing</c><00:07:12.319><c> the</c><00:07:12.479><c> security</c><00:07:13.120><c> of</c><00:07:13.280><c> the</c>
# ['without', 'sacrificing', 'the', 'security', 'of', 'the']
# ethereum<00:07:14.080><c> network</c><00:07:14.479><c> this</c><00:07:14.639><c> is</c><00:07:14.720><c> according</c><00:07:15.039><c> to</c>
# ['ethereum', 'network', 'this', 'is', 'according', 'to']
# open<00:07:15.440><c> seas</c><00:07:15.840><c> head</c>
# ['open', 'seas', 'head']
# of<00:07:16.560><c> product</c><00:07:17.599><c> he</c><00:07:17.840><c> says</c><00:07:18.319><c> we're</c><00:07:18.560><c> rolling</c><00:07:18.880><c> this</c>
# ['of', 'product', 'he', 'says', "we're", 'rolling', 'this']
# out
# ['out', 'of', 'product', 'he', 'says', "we're", 'rolling', 'this']
# not<00:07:19.919><c> only</c><00:07:20.319><c> to</c><00:07:20.560><c> better</c><00:07:20.800><c> support</c><00:07:21.360><c> existing</c>
# ['not', 'only', 'to', 'better', 'support', 'existing']
# immutablex<00:07:22.639><c> projects</c>
# ['immutablex', 'projects']
# but<00:07:23.520><c> for</c><00:07:23.759><c> future</c><00:07:24.160><c> game</c><00:07:24.400><c> developers</c><00:07:25.039><c> and</c>
# ['but', 'for', 'future', 'game', 'developers', 'and']
# players<00:07:25.680><c> on</c><00:07:25.919><c> openc</c>
# ['players', 'on', 'openc']
# who<00:07:26.800><c> will</c><00:07:26.960><c> benefit</c><00:07:27.440><c> from</c><00:07:27.599><c> the</c><00:07:27.840><c> scaling</c>
# ['who', 'will', 'benefit', 'from', 'the', 'scaling']
# solution<00:07:29.440><c> if</c><00:07:29.599><c> you</c><00:07:29.680><c> don't</c><00:07:29.759><c> know</c><00:07:29.919><c> immutable</c><00:07:30.400><c> x</c>
# ['solution', 'if', 'you', "don't", 'know', 'immutable', 'x']
# is<00:07:30.880><c> an</c><00:07:31.039><c> australian-based</c><00:07:31.919><c> company</c><00:07:32.319><c> that</c><00:07:32.560><c> is</c>
# ['is', 'an', 'australian-based', 'company', 'that', 'is']
# focusing<00:07:33.120><c> on</c><00:07:33.280><c> creating</c><00:07:33.680><c> a</c><00:07:33.840><c> more</c><00:07:34.080><c> accessible</c>
# ['focusing', 'on', 'creating', 'a', 'more', 'accessible']
# and<00:07:35.199><c> seamless</c><00:07:35.840><c> trading</c><00:07:36.319><c> platform</c><00:07:37.280><c> backed</c><00:07:37.599><c> by</c>
# ['and', 'seamless', 'trading', 'platform', 'backed', 'by']
# investors<00:07:38.400><c> like</c><00:07:38.639><c> naspers</c><00:07:39.199><c> ventures</c><00:07:39.680><c> galaxy</c>
# ['investors', 'like', 'naspers', 'ventures', 'galaxy']
# digital<00:07:40.479><c> and</c><00:07:40.560><c> apex</c>
# ['digital', 'and', 'apex']
# capital<00:07:42.000><c> partners</c><00:07:43.120><c> mutablex</c><00:07:43.759><c> is</c><00:07:43.919><c> the</c><00:07:44.160><c> first</c>
# ['capital', 'partners', 'mutablex', 'is', 'the', 'first']
# layer<00:07:44.960><c> two</c><00:07:45.199><c> scaling</c><00:07:45.599><c> solution</c><00:07:46.000><c> for</c><00:07:46.160><c> nfts</c><00:07:46.720><c> on</c>
# ['layer', 'two', 'scaling', 'solution', 'for', 'nfts', 'on']
# ethereum
# ['ethereum', 'layer', 'two', 'scaling', 'solution', 'for', 'nfts', 'on']
# instant<00:07:48.319><c> trade</c><00:07:48.560><c> confirmations</c><00:07:49.440><c> massive</c>
# ['instant', 'trade', 'confirmations', 'massive']
# scalability<00:07:50.720><c> zero</c><00:07:51.039><c> gas</c><00:07:51.360><c> fees</c><00:07:51.759><c> without</c><00:07:52.319><c> a</c>
# ['scalability', 'zero', 'gas', 'fees', 'without', 'a']
# compromise
# ['compromise', 'scalability', 'zero', 'gas', 'fees', 'without', 'a']
# to<00:07:53.759><c> user</c><00:07:54.479><c> custody</c><00:07:55.440><c> so</c><00:07:55.599><c> i</c><00:07:55.759><c> point</c><00:07:55.919><c> this</c><00:07:56.160><c> out</c>
# ['to', 'user', 'custody', 'so', 'i', 'point', 'this', 'out']
# because<00:07:58.080><c> a</c><00:07:58.319><c> lot</c><00:07:58.800><c> of</c><00:07:59.520><c> ethereum</c><00:08:00.080><c> critics</c><00:08:00.560><c> a</c><00:08:00.639><c> lot</c>
# ['because', 'a', 'lot', 'of', 'ethereum', 'critics', 'a', 'lot']
# of<00:08:00.960><c> bitcoin-only</c><00:08:01.680><c> people</c>
# ['of', 'bitcoin-only', 'people']
# say<00:08:02.400><c> ethereum</c><00:08:03.120><c> cannot</c><00:08:03.599><c> scale</c><00:08:04.160><c> people</c><00:08:04.479><c> aren't</c>
# ['say', 'ethereum', 'cannot', 'scale', 'people', "aren't"]
# going<00:08:04.879><c> to</c><00:08:05.039><c> build</c><00:08:05.280><c> on</c><00:08:05.440><c> ethereum</c><00:08:05.840><c> because</c><00:08:06.000><c> the</c>
# ['going', 'to', 'build', 'on', 'ethereum', 'because', 'the']
# gas<00:08:06.400><c> fees</c><00:08:06.639><c> are</c><00:08:06.800><c> too</c><00:08:07.039><c> high</c>
# ['gas', 'fees', 'are', 'too', 'high']
# and<00:08:08.000><c> again</c><00:08:08.240><c> i</c><00:08:08.400><c> point</c><00:08:08.720><c> out</c><00:08:09.199><c> right</c><00:08:09.440><c> now</c><00:08:10.319><c> it's</c>
# ['and', 'again', 'i', 'point', 'out', 'right', 'now', "it's"]
# actually<00:08:10.879><c> the</c><00:08:11.120><c> opposite</c><00:08:11.520><c> that's</c><00:08:11.840><c> trending</c><00:08:12.160><c> in</c>
# ['actually', 'the', 'opposite', "that's", 'trending', 'in']
# the<00:08:12.479><c> opposite</c><00:08:12.960><c> way</c>
# ['the', 'opposite', 'way']
# we'll<00:08:13.599><c> see</c><00:08:13.759><c> how</c><00:08:13.919><c> things</c><00:08:14.240><c> play</c><00:08:14.479><c> out</c><00:08:15.360><c> in</c><00:08:15.599><c> fact</c>
# ["we'll", 'see', 'how', 'things', 'play', 'out', 'in', 'fact']
# ethereum
# ['ethereum', "we'll", 'see', 'how', 'things', 'play', 'out', 'in', 'fact']
# layer<00:08:17.199><c> 2</c><00:08:17.520><c> ecosystem</c><00:08:18.240><c> ethereum</c><00:08:19.039><c> layer</c><00:08:19.440><c> 2</c>
# ['layer', '2', 'ecosystem', 'ethereum', 'layer', '2']
# solutions
# ['solutions', 'layer', '2', 'ecosystem', 'ethereum', 'layer', '2']
# this<00:08:21.199><c> is</c><00:08:21.360><c> what</c><00:08:21.520><c> that</c><00:08:21.840><c> ecosystem</c><00:08:22.479><c> looks</c><00:08:22.800><c> like</c>
# ['this', 'is', 'what', 'that', 'ecosystem', 'looks', 'like']
# march<00:08:23.680><c> 2021</c>
# ['march', '2021']
# plenty<00:08:25.280><c> of</c><00:08:25.360><c> things</c><00:08:25.680><c> in</c><00:08:25.759><c> the</c><00:08:25.840><c> pipeline</c><00:08:26.319><c> just</c>
# ['plenty', 'of', 'things', 'in', 'the', 'pipeline', 'just']
# wanted<00:08:26.720><c> to</c><00:08:26.800><c> point</c><00:08:27.039><c> this</c><00:08:27.199><c> out</c><00:08:27.680><c> and</c>
# ['wanted', 'to', 'point', 'this', 'out', 'and']
# with<00:08:28.319><c> ethereum</c><00:08:29.039><c> at</c><00:08:29.280><c> 1</c><00:08:30.319><c> 900</c>
# ['with', 'ethereum', 'at', '1', '900']
# very<00:08:31.759><c> close</c><00:08:32.000><c> to</c><00:08:32.080><c> 2</c><00:08:32.320><c> thousand</c><00:08:32.560><c> dollars</c>
# ['very', 'close', 'to', '2', 'thousand', 'dollars']
# consolidating<00:08:33.680><c> near</c><00:08:33.839><c> the</c><00:08:34.000><c> highs</c>
# ['consolidating', 'near', 'the', 'highs']
# in<00:08:35.039><c> what</c><00:08:35.360><c> world</c><00:08:36.399><c> doesn't</c><00:08:36.880><c> ethereum</c><00:08:37.519><c> do</c><00:08:37.760><c> well</c>
# ['in', 'what', 'world', "doesn't", 'ethereum', 'do', 'well']
# versus<00:08:38.719><c> the</c><00:08:38.880><c> us</c><00:08:39.279><c> dollar</c><00:08:39.760><c> this</c><00:08:40.080><c> cycle</c><00:08:40.640><c> i</c><00:08:40.719><c> mean</c>
# ['versus', 'the', 'us', 'dollar', 'this', 'cycle', 'i', 'mean']
# it's<00:08:41.120><c> pretty</c><00:08:41.360><c> obvious</c>
# ["it's", 'pretty', 'obvious']
# really<00:08:42.560><c> the</c><00:08:42.640><c> only</c><00:08:42.880><c> question</c><00:08:43.279><c> is</c><00:08:43.519><c> between</c>
# ['really', 'the', 'only', 'question', 'is', 'between']
# ethereum<00:08:44.560><c> maximalists</c><00:08:45.360><c> and</c><00:08:45.440><c> bitcoin</c>
# ['ethereum', 'maximalists', 'and', 'bitcoin']
# maximalists
# ['maximalists', 'ethereum', 'maximalists', 'and', 'bitcoin']
# everybody<00:08:47.279><c> i</c><00:08:47.360><c> don't</c><00:08:47.440><c> think</c><00:08:47.680><c> anybody</c>
# ['everybody', 'i', "don't", 'think', 'anybody']
# everybody<00:08:49.360><c> realizes</c><00:08:49.920><c> that</c><00:08:50.080><c> ethereum</c><00:08:50.480><c> is</c>
# ['everybody', 'realizes', 'that', 'ethereum', 'is']
# going<00:08:50.720><c> to</c><00:08:50.880><c> be</c><00:08:51.040><c> here</c><00:08:51.200><c> for</c><00:08:51.360><c> the</c><00:08:51.440><c> next</c><00:08:51.680><c> few</c><00:08:51.920><c> years</c>
# ['going', 'to', 'be', 'here', 'for', 'the', 'next', 'few', 'years']
# the<00:08:52.320><c> only</c><00:08:52.560><c> question</c><00:08:52.880><c> is</c><00:08:53.040><c> how</c><00:08:53.279><c> is</c><00:08:53.360><c> it</c><00:08:53.519><c> going</c><00:08:53.680><c> to</c>
# ['the', 'only', 'question', 'is', 'how', 'is', 'it', 'going', 'to']
# accrue<00:08:54.399><c> value</c>
# ['accrue', 'value']
# versus<00:08:55.519><c> bitcoin</c><00:08:55.920><c> and</c><00:08:56.080><c> if</c><00:08:56.160><c> you're</c><00:08:56.240><c> somebody</c>
# ['versus', 'bitcoin', 'and', 'if', "you're", 'somebody']
# like<00:08:56.720><c> nick</c><00:08:56.959><c> carter</c><00:08:57.440><c> you</c><00:08:57.519><c> think</c><00:08:57.760><c> it's</c><00:08:57.920><c> possible</c>
# ['like', 'nick', 'carter', 'you', 'think', "it's", 'possible']
# that<00:08:58.800><c> it</c><00:08:58.959><c> could</c><00:08:59.200><c> accrue</c><00:08:59.760><c> more</c><00:09:00.000><c> value</c><00:09:00.480><c> versus</c>
# ['that', 'it', 'could', 'accrue', 'more', 'value', 'versus']
# bitcoin<00:09:01.360><c> it's</c><00:09:01.600><c> a</c><00:09:01.800><c> possibility</c>
# ['bitcoin', "it's", 'a', 'possibility']
# speaking<00:09:03.920><c> about</c><00:09:04.320><c> ethereum</c><00:09:04.880><c> layer</c><00:09:05.200><c> 2</c>
# ['speaking', 'about', 'ethereum', 'layer', '2']
# solutions<00:09:05.920><c> here's</c><00:09:06.160><c> another</c><00:09:06.480><c> one</c>
# ['solutions', "here's", 'another', 'one']
# d5<00:09:07.839><c> platforms</c><00:09:08.640><c> zapper</c><00:09:09.120><c> and</c><00:09:09.360><c> ave</c><00:09:09.839><c> announce</c>
# ['d5', 'platforms', 'zapper', 'and', 'ave', 'announce']
# polygon<00:09:11.360><c> sidechain</c><00:09:12.320><c> integration</c><00:09:13.040><c> this</c><00:09:13.200><c> is</c>
# ['polygon', 'sidechain', 'integration', 'this', 'is']
# another
# ['another', 'polygon', 'sidechain', 'integration', 'this', 'is']
# scaling<00:09:15.360><c> solution</c><00:09:16.080><c> on</c><00:09:16.399><c> ethereum</c><00:09:17.440><c> as</c>
# ['scaling', 'solution', 'on', 'ethereum', 'as']
# crippling<00:09:18.320><c> high</c><00:09:18.640><c> gas</c><00:09:18.959><c> fees</c><00:09:19.279><c> put</c><00:09:19.519><c> scalability</c>
# ['crippling', 'high', 'gas', 'fees', 'put', 'scalability']
# in<00:09:20.480><c> the</c><00:09:20.640><c> spotlight</c>
# ['in', 'the', 'spotlight']
# and<00:09:21.680><c> multiple</c><00:09:22.160><c> platforms</c><00:09:22.720><c> rushed</c><00:09:23.040><c> to</c><00:09:23.120><c> become</c>
# ['and', 'multiple', 'platforms', 'rushed', 'to', 'become']
# the<00:09:23.680><c> preferred</c><00:09:24.320><c> home</c>
# ['the', 'preferred', 'home']
# of<00:09:24.880><c> ethereum's</c><00:09:25.360><c> decentralized</c><00:09:26.000><c> finance</c><00:09:26.399><c> or</c>
# ['of', "ethereum's", 'decentralized', 'finance', 'or']
# defy<00:09:26.959><c> ecosystem</c>
# ['defy', 'ecosystem']
# layer<00:09:28.560><c> 2</c><00:09:29.040><c> sidechain</c><00:09:29.920><c> polygon</c><00:09:30.560><c> formerly</c><00:09:30.959><c> matic</c>
# ['layer', '2', 'sidechain', 'polygon', 'formerly', 'matic']
# ...
# ['big', 'wins', 'today', 'both', 'lending', 'protocol', 'ave']
# and<00:09:39.200><c> the</c><00:09:39.360><c> portfolio</c><00:09:40.000><c> management</c><00:09:40.480><c> and</c><00:09:40.640><c> batched</c>
# ['and', 'the', 'portfolio', 'management', 'and', 'batched']
# transaction<00:09:41.760><c> platform</c>
# ['transaction', 'platform']
# zapper<00:09:43.040><c> have</c><00:09:43.279><c> announced</c><00:09:43.920><c> that</c><00:09:44.080><c> they</c><00:09:44.240><c> will</c><00:09:44.399><c> be</c>
# ['zapper', 'have', 'announced', 'that', 'they', 'will', 'be']
# offering<00:09:45.040><c> implementations</c>
# ['offering', 'implementations']
# on<00:09:46.399><c> polygon</c><00:09:47.519><c> ave</c><00:09:47.920><c> will</c><00:09:48.000><c> be</c><00:09:48.160><c> launching</c><00:09:48.560><c> a</c>
# ['on', 'polygon', 'ave', 'will', 'be', 'launching', 'a']
# trimmed<00:09:49.200><c> down</c><00:09:49.519><c> fork</c><00:09:49.839><c> of</c><00:09:49.920><c> its</c><00:09:50.080><c> money</c><00:09:50.320><c> market</c>
# ['trimmed', 'down', 'fork', 'of', 'its', 'money', 'market']
# with<00:09:51.120><c> seven</c><00:09:51.519><c> assets</c><00:09:52.000><c> available</c><00:09:52.480><c> for</c>
# ['with', 'seven', 'assets', 'available', 'for']
# borrowing<00:09:53.120><c> and</c><00:09:53.200><c> lending</c><00:09:53.600><c> and</c><00:09:53.680><c> launch</c>
# ['borrowing', 'and', 'lending', 'and', 'launch']
# and<00:09:54.720><c> zapper</c><00:09:55.200><c> will</c><00:09:55.440><c> enable</c><00:09:55.920><c> ethereum</c><00:09:56.320><c> to</c>
# ['and', 'zapper', 'will', 'enable', 'ethereum', 'to']
# polygon<00:09:56.959><c> transfers</c><00:09:57.519><c> in</c><00:09:57.600><c> the</c><00:09:57.680><c> first</c><00:09:58.080><c> step</c>
# ['polygon', 'transfers', 'in', 'the', 'first', 'step']
# towards<00:09:59.120><c> enabling</c><00:09:59.760><c> cross-chain</c><00:10:00.959><c> zaps</c>
# ['towards', 'enabling', 'cross-chain', 'zaps']
# its<00:10:02.320><c> term</c><00:10:02.720><c> for</c><00:10:02.959><c> multi-transaction</c>
# ['its', 'term', 'for', 'multi-transaction']
# single-click<00:10:04.880><c> deposits</c>
# ['single-click', 'deposits']
# and<00:10:06.160><c> withdrawals</c><00:10:07.120><c> so</c><00:10:07.360><c> much</c><00:10:07.519><c> like</c><00:10:07.760><c> immutable</c><00:10:08.320><c> x</c>
# ['and', 'withdrawals', 'so', 'much', 'like', 'immutable', 'x']
# polygon<00:10:09.760><c> formerly</c><00:10:10.160><c> mo</c><00:10:10.560><c> formerly</c><00:10:11.040><c> matic</c><00:10:11.680><c> is</c>
# ['polygon', 'formerly', 'mo', 'formerly', 'matic', 'is']
# another
# ['another', 'polygon', 'formerly', 'mo', 'formerly', 'matic', 'is']
# layer<00:10:13.279><c> two</c><00:10:13.839><c> scaling</c><00:10:14.480><c> solution</c><00:10:15.040><c> and</c><00:10:15.360><c> you</c><00:10:15.519><c> can</c>
# ['layer', 'two', 'scaling', 'solution', 'and', 'you', 'can']
# check<00:10:16.000><c> out</c>
# ['check', 'out']
# the<00:10:16.959><c> many</c><00:10:17.519><c> layer</c><00:10:17.920><c> 2</c><00:10:18.640><c> solutions</c><00:10:19.200><c> in</c><00:10:19.279><c> ethereum's</c>
# ['the', 'many', 'layer', '2', 'solutions', 'in', "ethereum's"]
# ecosystem
# ['ecosystem', 'the', 'many', 'layer', '2', 'solutions', 'in', "ethereum's"]
# right<00:10:21.279><c> here</c><00:10:22.320><c> the</c><00:10:22.480><c> weekend</c><00:10:23.360><c> clears</c><00:10:23.839><c> his</c>
# ['right', 'here', 'the', 'weekend', 'clears', 'his']
# schedule<00:10:24.800><c> for</c><00:10:24.959><c> an</c>
# ['schedule', 'for', 'an']
# nft<00:10:26.399><c> mic</c><00:10:27.120><c> drop</c>
# ['nft', 'mic', 'drop']
# where<00:10:28.480><c> is</c><00:10:28.560><c> that</c><00:10:28.720><c> tweet</c><00:10:29.040><c> here</c><00:10:29.200><c> it</c><00:10:29.279><c> is</c><00:10:29.440><c> the</c>
# ['where', 'is', 'that', 'tweet', 'here', 'it', 'is', 'the']
# weekend<00:10:29.920><c> excited</c><00:10:30.240><c> to</c><00:10:30.399><c> announce</c><00:10:30.720><c> that</c><00:10:30.800><c> my</c>
# ['weekend', 'excited', 'to', 'announce', 'that', 'my']
# first<00:10:31.279><c> nft</c><00:10:31.839><c> drop</c><00:10:32.240><c> is</c><00:10:32.399><c> taking</c><00:10:32.800><c> place</c><00:10:33.040><c> on</c>
# ['first', 'nft', 'drop', 'is', 'taking', 'place', 'on']
# saturday<00:10:33.839><c> at</c><00:10:34.000><c> 2</c><00:10:34.240><c> p.m</c><00:10:34.560><c> eastern</c><00:10:35.040><c> standard</c><00:10:35.360><c> time</c>
# ['saturday', 'at', '2', 'p.m', 'eastern', 'standard', 'time']
# nifty<00:10:36.160><c> gateway</c><00:10:36.880><c> the</c><00:10:37.040><c> collection</c><00:10:37.440><c> will</c>
# ['nifty', 'gateway', 'the', 'collection', 'will']
# feature<00:10:38.320><c> new</c><00:10:38.640><c> music</c><00:10:39.120><c> and</c><00:10:39.200><c> limited</c><00:10:39.680><c> edition</c>
# ['feature', 'new', 'music', 'and', 'limited', 'edition']
# art
# ['art', 'feature', 'new', 'music', 'and', 'limited', 'edition']
# i<00:10:41.040><c> developed</c><00:10:41.440><c> the</c><00:10:41.519><c> artwork</c><00:10:42.160><c> with</c><00:10:42.399><c> strange</c>
# ['i', 'developed', 'the', 'artwork', 'with', 'strange']
# loop<00:10:43.279><c> studios</c>
# ['loop', 'studios']
# so<00:10:44.320><c> nifty</c><00:10:44.640><c> gateway</c><00:10:45.200><c> is</c><00:10:45.600><c> gemini's</c><00:10:46.800><c> nft</c>
# ['so', 'nifty', 'gateway', 'is', "gemini's", 'nft']
# marketplace<00:10:48.399><c> also</c><00:10:48.880><c> running</c><00:10:49.200><c> on</c><00:10:49.440><c> ethereum</c><00:10:50.079><c> and</c>
# ['marketplace', 'also', 'running', 'on', 'ethereum', 'and']
# just<00:10:50.480><c> another</c>
# ['just', 'another']
# huge<00:10:52.160><c> artists</c><00:10:52.959><c> with</c><00:10:53.279><c> mil</c><00:10:53.839><c> huge</c><00:10:54.240><c> artist</c>
# ['huge', 'artists', 'with', 'mil', 'huge', 'artist']
# with<00:10:54.959><c> millions</c><00:10:55.360><c> and</c><00:10:55.519><c> millions</c><00:10:55.920><c> of</c><00:10:56.000><c> followers</c>
# ['with', 'millions', 'and', 'millions', 'of', 'followers']
# telling<00:10:57.519><c> their</c><00:10:57.839><c> fans</c>
# ['telling', 'their', 'fans']
# go<00:10:58.959><c> on</c><00:10:59.120><c> over</c><00:10:59.440><c> to</c><00:10:59.600><c> this</c><00:10:59.839><c> nft</c><00:11:00.320><c> marketplace</c><00:11:01.360><c> get</c>
# ['go', 'on', 'over', 'to', 'this', 'nft', 'marketplace', 'get']
# some<00:11:01.839><c> ethereum</c>
# ['some', 'ethereum']
# get<00:11:02.800><c> off</c><00:11:03.040><c> zero</c><00:11:03.519><c> with</c><00:11:03.680><c> ethereum</c><00:11:04.640><c> and</c><00:11:04.880><c> buy</c><00:11:05.279><c> my</c>
# ['get', 'off', 'zero', 'with', 'ethereum', 'and', 'buy', 'my']
# limited<00:11:06.000><c> edition</c>
# ['limited', 'edition']
# nft<00:11:08.320><c> quite</c><00:11:08.800><c> another</c><00:11:09.200><c> reason</c>
# ['nft', 'quite', 'another', 'reason']
# that<00:11:10.000><c> i'm</c><00:11:10.160><c> sure</c><00:11:10.560><c> if</c><00:11:10.640><c> you're</c><00:11:10.880><c> looking</c><00:11:11.360><c> at</c><00:11:11.680><c> the</c>
# ['that', "i'm", 'sure', 'if', "you're", 'looking', 'at', 'the']
# different<00:11:12.240><c> metrics</c>
# ['different', 'metrics']
# like<00:11:13.760><c> nick</c><00:11:14.079><c> carter</c><00:11:14.480><c> is</c><00:11:14.560><c> he's</c><00:11:14.800><c> probably</c><00:11:15.200><c> seeing</c>
# ['like', 'nick', 'carter', 'is', "he's", 'probably', 'seeing']
# that<00:11:16.000><c> ethereum's</c><00:11:16.720><c> ecosystem</c><00:11:17.440><c> is</c><00:11:17.600><c> growing</c>
# ['that', "ethereum's", 'ecosystem', 'is', 'growing']
# whether<00:11:18.160><c> it</c><00:11:18.240><c> be</c><00:11:18.480><c> users</c><00:11:18.880><c> whether</c><00:11:19.120><c> it</c><00:11:19.120><c> be</c><00:11:19.279><c> layer</c>
# ['whether', 'it', 'be', 'users', 'whether', 'it', 'be', 'layer']
# 2<00:11:19.920><c> whether</c><00:11:20.240><c> it</c><00:11:20.320><c> be</c><00:11:20.480><c> whatever</c>
# ['2', 'whether', 'it', 'be', 'whatever']
# and<00:11:21.360><c> ether</c><00:11:22.000><c> is</c><00:11:22.240><c> certainly</c><00:11:23.040><c> one</c><00:11:23.519><c> to</c><00:11:23.680><c> watch</c>
# ['and', 'ether', 'is', 'certainly', 'one', 'to', 'watch']
# now<00:11:25.279><c> today</c><00:11:25.680><c> is</c><00:11:25.839><c> april</c><00:11:26.240><c> 1st</c><00:11:26.640><c> as</c><00:11:26.800><c> we</c><00:11:27.040><c> end</c><00:11:27.360><c> q1</c>
# ['now', 'today', 'is', 'april', '1st', 'as', 'we', 'end', 'q1']
# and<00:11:28.160><c> get</c><00:11:28.480><c> into</c><00:11:28.720><c> q2</c><00:11:29.279><c> i</c><00:11:29.360><c> want</c><00:11:29.519><c> to</c><00:11:29.600><c> congratulate</c>
# ['and', 'get', 'into', 'q2', 'i', 'want', 'to', 'congratulate']
# everybody
# ['everybody', 'and', 'get', 'into', 'q2', 'i', 'want', 'to', 'congratulate']
# who<00:11:31.600><c> came</c><00:11:31.920><c> out</c><00:11:32.399><c> on</c><00:11:32.640><c> top</c><00:11:33.200><c> in</c><00:11:33.440><c> q1</c><00:11:34.079><c> um</c>
# ['who', 'came', 'out', 'on', 'top', 'in', 'q1', 'um']
# i<00:11:34.720><c> i</c><00:11:34.800><c> think</c><00:11:35.040><c> a</c><00:11:35.120><c> lot</c><00:11:35.279><c> of</c><00:11:35.440><c> people</c><00:11:35.680><c> are</c><00:11:35.920><c> up</c><00:11:36.160><c> after</c>
# ['i', 'i', 'think', 'a', 'lot', 'of', 'people', 'are', 'up', 'after']
# q1
# ['q1', 'i', 'i', 'think', 'a', 'lot', 'of', 'people', 'are', 'up', 'after']
# i<00:11:37.760><c> think</c><00:11:38.000><c> a</c><00:11:38.079><c> lot</c><00:11:38.240><c> of</c><00:11:38.399><c> people</c><00:11:38.640><c> are</c><00:11:38.800><c> up</c><00:11:39.680><c> let</c><00:11:39.839><c> me</c>
# ['i', 'think', 'a', 'lot', 'of', 'people', 'are', 'up', 'let', 'me']
# know<00:11:40.079><c> in</c><00:11:40.160><c> the</c><00:11:40.320><c> comments</c>
# ['know', 'in', 'the', 'comments']
# which<00:11:41.360><c> coin</c><00:11:41.839><c> did</c><00:11:42.079><c> you</c><00:11:42.240><c> the</c><00:11:42.399><c> best</c><00:11:42.880><c> in</c><00:11:42.959><c> q1</c><00:11:43.440><c> and</c>
# ['which', 'coin', 'did', 'you', 'the', 'best', 'in', 'q1', 'and']
# let<00:11:43.600><c> me</c><00:11:43.680><c> know</c><00:11:43.839><c> in</c><00:11:43.920><c> the</c><00:11:44.000><c> comments</c><00:11:44.320><c> which</c><00:11:44.560><c> coin</c>
# ['let', 'me', 'know', 'in', 'the', 'comments', 'which', 'coin']
# you<00:11:45.040><c> think</c><00:11:45.360><c> is</c><00:11:45.519><c> going</c><00:11:45.680><c> to</c><00:11:45.760><c> do</c><00:11:45.920><c> you</c><00:11:46.079><c> the</c><00:11:46.160><c> best</c><00:11:46.560><c> in</c>
# ['you', 'think', 'is', 'going', 'to', 'do', 'you', 'the', 'best', 'in']
# q2
# ['q2', 'you', 'think', 'is', 'going', 'to', 'do', 'you', 'the', 'best', 'in']
# my<00:11:48.160><c> personal</c><00:11:48.640><c> strategy</c><00:11:49.360><c> is</c><00:11:49.680><c> um</c><00:11:50.079><c> you</c><00:11:50.160><c> know</c>
# ['my', 'personal', 'strategy', 'is', 'um', 'you', 'know']
# after<00:11:51.200><c> i</c><00:11:51.360><c> see</c><00:11:51.600><c> these</c><00:11:51.839><c> coins</c>
# ['after', 'i', 'see', 'these', 'coins']
# do<00:11:53.040><c> a</c><00:11:53.200><c> certain</c><00:11:53.519><c> percentage</c><00:11:54.320><c> and</c><00:11:54.480><c> it</c><00:11:54.560><c> could</c><00:11:54.720><c> be</c>
# ['do', 'a', 'certain', 'percentage', 'and', 'it', 'could', 'be']
# a<00:11:54.959><c> while</c><00:11:55.360><c> i'm</c><00:11:55.519><c> waiting</c>
# ['a', 'while', "i'm", 'waiting']
# i<00:11:56.639><c> always</c><00:11:57.440><c> you</c><00:11:57.600><c> know</c><00:11:57.839><c> take</c><00:11:58.079><c> out</c><00:11:58.320><c> some</c><00:11:58.480><c> gains</c>
# ['i', 'always', 'you', 'know', 'take', 'out', 'some', 'gains']
# make<00:11:59.120><c> sure</c><00:11:59.440><c> i</c>
# ['make', 'sure', 'i']
# increase<00:12:00.160><c> my</c><00:12:00.320><c> bitcoin</c><00:12:00.720><c> stash</c><00:12:01.200><c> and</c><00:12:01.279><c> i</c><00:12:01.519><c> always</c>
# ['increase', 'my', 'bitcoin', 'stash', 'and', 'i', 'always']
# keep<00:12:02.240><c> a</c><00:12:02.320><c> moon</c><00:12:02.639><c> bag</c><00:12:02.959><c> because</c><00:12:03.120><c> you</c><00:12:03.200><c> just</c><00:12:03.440><c> don't</c>
# ['keep', 'a', 'moon', 'bag', 'because', 'you', 'just', "don't"]
# know<00:12:03.920><c> how</c><00:12:04.160><c> high</c><00:12:04.399><c> these</c><00:12:04.560><c> things</c><00:12:04.800><c> can</c><00:12:04.959><c> go</c><00:12:05.200><c> in</c><00:12:05.279><c> a</c>
# ['know', 'how', 'high', 'these', 'things', 'can', 'go', 'in', 'a']
# bull<00:12:05.519><c> market</c><00:12:05.839><c> and</c><00:12:05.920><c> i</c><00:12:06.079><c> scale</c><00:12:06.399><c> out</c>
# ['bull', 'market', 'and', 'i', 'scale', 'out']
# so<00:12:07.360><c> that's</c><00:12:07.519><c> my</c><00:12:07.760><c> strategy</c><00:12:08.320><c> that's</c><00:12:08.480><c> the</c><00:12:08.560><c> way</c><00:12:08.720><c> i'm</c>
# ['so', "that's", 'my', 'strategy', "that's", 'the', 'way', "i'm"]
# thinking<00:12:09.040><c> about</c><00:12:09.279><c> it</c><00:12:09.760><c> alright</c><00:12:10.079><c> guys</c>
# ['thinking', 'about', 'it', 'alright', 'guys']
# great<00:12:11.279><c> video</c><00:12:11.680><c> today</c><00:12:12.320><c> subscribe</c><00:12:13.440><c> i'll</c><00:12:13.600><c> see</c><00:12:13.760><c> you</c>
# ['great', 'video', 'today', 'subscribe', "i'll", 'see', 'you']
# tomorrow
# ['tomorrow', 'great', 'video', 'today', 'subscribe', "i'll", 'see', 'you']
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-3-d29d714c93d3> in <module>
#      11
#      12
# ---> 13 prepare_data_for_manual_labelling([subtitle_file_paths[0]],
#      14                                   [podcast_names[0]],
#      15                                   "sentiment_labels_altcoin_daily_210401.csv",
#
# <ipython-input-2-b714f1578fd9> in prepare_data_for_manual_labelling(subtitle_files, podcast_names, output_file_name, chunk_size, min_chunk_size, filter_labels, filter_labels_proportions, guess_coin)
#      53         df["Coin"][df["Auto_Label"].isin(["BTC","ETH","DOGE"])] = df["Auto_Label"]
#      54
# ---> 55     df.to_csv(output_file_name, index=False)
#      56
#      57
#
# ~\Anaconda3\envs\nlp3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\Anaconda3\envs\nlp3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\Anaconda3\envs\nlp3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\Anaconda3\envs\nlp3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: 'sentiment_labels_altcoin_daily_210401.csv'

# %%
# Fix timestamps

df_old = pd.read_csv("C:/Users/Tristan/nlp_project/generated_data_for_labelling/sentiment_labels_altcoin_daily_210401_to_210531.csv")

df_corrected = pd.DataFrame(columns=["Start_Time_c", "End_Time_c", "Text"])

folder_path = "D:/nlp_project_d/podcast_data/labelling/batch_1/"
all_file_names = listdir(folder_path)
subtitle_file_paths = []
podcast_names = []

for file_name in all_file_names:
    if file_name[-4:] == ".vtt":
        subtitle_file = folder_path + '/' + file_name
        
        text_chunks, chunk_start_times, chunk_end_times = SubtitleProcessing.generate_text_chunks(subtitle_file, 25, 10)
        
        if text_chunks is None:
            continue
        
        df_c_new = pd.DataFrame(columns=df_corrected.columns)
        
        text_chunks = [" ".join(chunk) for chunk in text_chunks]
        df_c_new["Text"] = text_chunks
        
        df_c_new["Start_Time_c"] = chunk_start_times
        df_c_new["End_Time_c"] = chunk_end_times

        df_corrected = df_corrected.append(df_c_new, ignore_index=True) 

df_join = df_old.join(df_corrected.set_index("Text"), on="Text")

df_join.to_csv("corrected_timestamps.csv", index=False)
# Out:
# Individual word times are not supported for file: D:/nlp_project_d/podcast_data/labelling/batch_1//Altcoin Daily_20210419_BREAKING - Ethereum ETF Approved! United States of America Bitcoin ETF Update! Cryptocurrency News.en.vtt
# Could not generate text chunks for file: D:/nlp_project_d/podcast_data/labelling/batch_1//Altcoin Daily_20210419_BREAKING - Ethereum ETF Approved! United States of America Bitcoin ETF Update! Cryptocurrency News.en.vtt
# Individual word times are not supported for file: D:/nlp_project_d/podcast_data/labelling/batch_1//Altcoin Daily_20210505_Unilayer Platform Review_Walkthrough!_ DeFi in Cryptocurrency GROWING BIGGER!.en.vtt
# Could not generate text chunks for file: D:/nlp_project_d/podcast_data/labelling/batch_1//Altcoin Daily_20210505_Unilayer Platform Review_Walkthrough!_ DeFi in Cryptocurrency GROWING BIGGER!.en.vtt
